# %% [markdown]
# # Overview
#
# This notebook presents an LSTM recurrent neural network demo using TensorFlow - Keras.
#
#
# References:
# * Much of this work is inspired from [amirrezaeian - Github](https://github.com/amirrezaeian/Individual-household-electric-power-consumption-Data-Set-/blob/master/data_e_power.ipynb)
# * https://colah.github.io/posts/2015-08-Understanding-LSTMs/
# * https://towardsdatascience.com/illustrated-guide-to-lstms-and-gru-s-a-step-by-step-explanation-44e9eb85bf21

# %% [markdown]
#  ![image.png](attachment:image.png)

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sagemaker
import boto3
import datetime
from pathlib import Path
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks

# %% [markdown]
# # Data
#
# http://archive.ics.uci.edu/ml/datasets/Individual+household+electric+power+consumption
#
# This data represents 2075259 measurements gathered each minute in a house located in Sceaux (7km of Paris, France) between December 2006 and November 2010 (47 months).
#
# **Data Details**
# 1. date: Date in format dd/mm/yyyy
# 2. time: time in format hh:mm:ss
# 3. global_active_power: household global minute-averaged active power (in kilowatt)
# 4. global_reactive_power: household global minute-averaged reactive power (in kilowatt)
# 5. voltage: minute-averaged voltage (in volt)
# 6. global_intensity: household global minute-averaged current intensity (in ampere)
# 7. sub_metering_1: energy sub-metering No. 1 (in watt-hour of active energy). It corresponds to the kitchen, containing mainly a dishwasher, an oven and a microwave (hot plates are not electric but gas powered).
# 8. sub_metering_2: energy sub-metering No. 2 (in watt-hour of active energy). It corresponds to the laundry room, containing a washing-machine, a tumble-drier, a refrigerator and a light.
# 9. sub_metering_3: energy sub-metering No. 3 (in watt-hour of active energy). It corresponds to an electric water-heater and an air-conditioner.
#
# **Notes:**
# 1. (global_active_power*1000/60 - sub_metering_1 - sub_metering_2 - sub_metering_3) represents the active energy consumed every minute (in watt hour) in the household by electrical equipment not measured in sub-meterings 1, 2 and 3.
# 2. The dataset contains some missing values in the measurements (nearly 1,25% of the rows). All calendar timestamps are present in the dataset but for some timestamps, the measurement values are missing: a missing value is represented by the absence of value between two consecutive semi-colon attribute separators. For instance, the dataset shows missing values on April 28, 2007.

# %% [markdown]
# ## Import Data

# %%
# !wget http://archive.ics.uci.edu/ml/machine-learning-databases/00235/household_power_consumption.zip

# %%
# !unzip household_power_consumption.zip

# %%
df = pd.read_csv('household_power_consumption.txt', sep=';',low_memory=False, parse_dates={'dt' : ['Date', 'Time']}, infer_datetime_format=True, na_values=['nan','?'], index_col='dt')

# %%
print(df.shape)
df.head()

# %% [markdown]
# ## Data Cleaning and Prep

# %% [markdown]
# ### Feature Engineering

# %%
# Feature Engineering
# add a column for for the remainder of sub metering
values = df.values.astype('float32')
df['Sub_metering_4'] = (values[:,0] * 1000 / 60) - (values[:,4] + values[:,5] + values[:,6])

# %%
df.head()

# %% [markdown]
# ### Missing Values

# %%
# check for missing values
df.isnull().sum()

# %%
# Fill Missing Values with the Mean of the Column

for j in range(0,8):        
        df.iloc[:,j]=df.iloc[:,j].fillna(df.iloc[:,j].mean())

# %%
# check for missing values
df.isnull().sum()

# %% [markdown]
# ### Resample and Save

# %%
## resampling of data over hour, this makes the dataset much easier to analyze and train on
df_resample = df.resample('h').mean() 
df_resample.shape

# %%
# save updated dataset
df_resample.to_csv('household_power_consumption_clean.csv')

# %%
# optional - load dataset
df = pd.read_csv('household_power_consumption_clean.csv', infer_datetime_format=True, index_col='dt')
df.head()
# Out:
#                      Global_active_power  Global_reactive_power     Voltage  \
# dt
# 2006-12-16 17:00:00             4.222889               0.229000  234.643889
# 2006-12-16 18:00:00             3.632200               0.080033  234.580167
# 2006-12-16 19:00:00             3.400233               0.085233  233.232500
# 2006-12-16 20:00:00             3.268567               0.075100  234.071500
# 2006-12-16 21:00:00             3.056467               0.076667  237.158667
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# dt
# 2006-12-16 17:00:00         18.100000             0.0        0.527778
# 2006-12-16 18:00:00         15.600000             0.0        6.716667
# 2006-12-16 19:00:00         14.503333             0.0        1.433333
# 2006-12-16 20:00:00         13.916667             0.0        0.000000
# 2006-12-16 21:00:00         13.046667             0.0        0.416667
#
#                      Sub_metering_3  Sub_metering_4
# dt
# 2006-12-16 17:00:00       16.861111       52.992590
# 2006-12-16 18:00:00       16.866667       36.953335
# 2006-12-16 19:00:00       16.683333       38.553890
# 2006-12-16 20:00:00       16.783333       37.692780
# 2006-12-16 21:00:00       17.216667       33.307777

# %%
len(df)
# Out:
# 34589

# %% [markdown]
# ### Train | Val | Test Split
#
# The goal for the split is to have the splits continous and the val and test sets should be the most recent data.  We can't do a random split that is typically done for classification problems since it is too easy to predict the missing data in a time series.  For further reading see this great [fastai post](https://www.fast.ai/2017/11/13/validation-sets/)

# %%
# sort
df.sort_index(inplace=True)

trainpct = 0.7
trainidx = int(np.round(len(df)*trainpct))
train_df = df.iloc[0:trainidx,:]

valpct = 0.2
validx = int(np.round(len(df)*(trainpct+valpct)))
val_df = df.iloc[trainidx:validx,:]
             
test_df = df.iloc[validx::,:]

# %% [markdown]
# ### Scaling and Normalization
#
# Any Scaling and Normalization is done from the training dataset only.  This is then applied to the validation and testing datasets.

# %%
# scale data between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(train_df.values)

train_scaled = scaler.transform(train_df.values)
val_scaled = scaler.transform(val_df.values)
test_scaled = scaler.transform(test_df.values)

# back to pandas
train_scaled_df = pd.DataFrame(train_scaled,columns=train_df.columns,index=train_df.index)
val_scaled_df = pd.DataFrame(val_scaled,columns=val_df.columns,index=val_df.index)
test_scaled_df = pd.DataFrame(test_scaled,columns=test_df.columns,index=test_df.index)

# %% [markdown]
# ### Resize for LSTM

# %% [markdown]
# For an LSTM the data must be in 3 dimensions - (total_time - lookback) x (lookback) x (variables)

# %%
## create a list of all parameters for seq_length timestamps to be used for prediction models ##
def gen_sequence(id_df, seq_length, seq_cols, step=1):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    data_array = id_df[seq_cols].values
    num_elements = data_array.shape[0]
    for start, stop in zip(range(0, num_elements-seq_length, step), range(seq_length, num_elements, step)):
        yield data_array[start:stop, :]

def build_datasets_rnn(df,seq_length,in_params,out_params):
    """ Function to reformat the pandas dataframe so it can be used in the RNN.  The output will be a numpy array
    with the shape of len(df)-seq_length x seq_length x len(in_params).  The out_array is the prediction variable.  
    It is one time step ahead.  For an example, if the seq_lenght was 10 then the input array would represent t-1 to t-10
    and the out array would be at time t"""
    
    # build X
    seq_array = np.empty([len(df) - seq_length, seq_length, len(in_params)], dtype=np.float32)
    arr = list(gen_sequence(df,seq_length,in_params))
    for j in range(len(df)-seq_length):
        seq_array[j,:,:] = arr[j]
        
    # build Y
    out_array = df[out_params].values[seq_length::]
    
    return seq_array,out_array

# %%
lookback = 48
X_train,Y_train = build_datasets_rnn(train_scaled_df,lookback,['Global_reactive_power', 'Voltage','Global_intensity', 'Sub_metering_1', 'Sub_metering_2','Sub_metering_3', 'Sub_metering_4'],['Global_active_power'])
X_val,Y_val = build_datasets_rnn(val_scaled_df,lookback,['Global_reactive_power', 'Voltage','Global_intensity', 'Sub_metering_1', 'Sub_metering_2','Sub_metering_3', 'Sub_metering_4'],['Global_active_power'])
X_test,Y_test = build_datasets_rnn(test_scaled_df,lookback,['Global_reactive_power', 'Voltage','Global_intensity', 'Sub_metering_1', 'Sub_metering_2','Sub_metering_3', 'Sub_metering_4'],['Global_active_power'])

# %%
# save data 
np.savez_compressed('training.npz', x=X_train, y=Y_train)
np.savez_compressed('testing.npz', x=X_test, y=Y_test)
np.savez_compressed('validation.npz', x=X_val, y=Y_val)

# %% [markdown]
# # LSTM Model
#
# Define the model architecture
#
# Goal is to predict global active power using the other variables with a look back of 48 hours

# %%
neurons = 64
batch_size = 2
epochs = 15

# %%
model = tf.keras.Sequential()

model.add(layers.LSTM(
    X_train.shape[1],
    input_shape=(X_train.shape[1],X_train.shape[2]),
    return_sequences=True,
    #dropout=0.2,
    #recurrent_dropout=0.2
    ))

model.add(layers.LSTM(
    neurons,
    return_sequences=False,
    #dropout=0.2,
    #recurrent_dropout=0.2
    ))

model.add(layers.Dense(neurons,activation="relu"))

model.add(layers.Dense(Y_train.shape[1]))

model.compile(loss="mse", optimizer="adam", metrics=['mae'])

print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 48, 48)            10752
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 64)                28928
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 43,905
# Trainable params: 43,905
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callback_list = []
cp = callbacks.ModelCheckpoint(filepath="lstm_demo.{epoch:02d}.hdf5",verbose=1)
callback_list.append(cp)

# %% [markdown]
# # Training

# %%
# %time
lstm_history = model.fit(X_train,Y_train, epochs=epochs, batch_size=batch_size, 
                                                validation_data=(X_val, Y_val),
                                                verbose=1, callbacks=callback_list,shuffle=False)
# Out:
# CPU times: user 6 µs, sys: 1e+03 ns, total: 7 µs
# Wall time: 13.8 µs
# Train on 24164 samples, validate on 6870 samples
# Epoch 1/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0083 - mean_absolute_error: 0.0640
# Epoch 00001: saving model to lstm_demo.01.hdf5
# 24164/24164 [==============================] - 7s 285us/sample - loss: 0.0082 - mean_absolute_error: 0.0640 - val_loss: 0.0074 - val_mean_absolute_error: 0.0620
# Epoch 2/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0086 - mean_absolute_error: 0.0663
# Epoch 00002: saving model to lstm_demo.02.hdf5
# 24164/24164 [==============================] - 7s 286us/sample - loss: 0.0086 - mean_absolute_error: 0.0663 - val_loss: 0.0085 - val_mean_absolute_error: 0.0647
# Epoch 3/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0091 - mean_absolute_error: 0.0691
# Epoch 00003: saving model to lstm_demo.03.hdf5
# 24164/24164 [==============================] - 7s 285us/sample - loss: 0.0091 - mean_absolute_error: 0.0691 - val_loss: 0.0095 - val_mean_absolute_error: 0.0701
# Epoch 4/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0105 - mean_absolute_error: 0.0754
# Epoch 00004: saving model to lstm_demo.04.hdf5
# 24164/24164 [==============================] - 7s 289us/sample - loss: 0.0105 - mean_absolute_error: 0.0754 - val_loss: 0.0118 - val_mean_absolute_error: 0.0801
# Epoch 5/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0092 - mean_absolute_error: 0.0688
# Epoch 00005: saving model to lstm_demo.05.hdf5
# 24164/24164 [==============================] - 7s 288us/sample - loss: 0.0092 - mean_absolute_error: 0.0687 - val_loss: 0.0075 - val_mean_absolute_error: 0.0608
# Epoch 6/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0080 - mean_absolute_error: 0.0613
# Epoch 00006: saving model to lstm_demo.06.hdf5
# 24164/24164 [==============================] - 7s 297us/sample - loss: 0.0079 - mean_absolute_error: 0.0613 - val_loss: 0.0072 - val_mean_absolute_error: 0.0601
# Epoch 7/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0078 - mean_absolute_error: 0.0608
# Epoch 00007: saving model to lstm_demo.07.hdf5
# 24164/24164 [==============================] - 7s 287us/sample - loss: 0.0078 - mean_absolute_error: 0.0608 - val_loss: 0.0072 - val_mean_absolute_error: 0.0598
# Epoch 8/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0078 - mean_absolute_error: 0.0606
# Epoch 00008: saving model to lstm_demo.08.hdf5
# 24164/24164 [==============================] - 7s 288us/sample - loss: 0.0078 - mean_absolute_error: 0.0606 - val_loss: 0.0071 - val_mean_absolute_error: 0.0594
# Epoch 9/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0077 - mean_absolute_error: 0.0603
# Epoch 00009: saving model to lstm_demo.09.hdf5
# 24164/24164 [==============================] - 7s 289us/sample - loss: 0.0077 - mean_absolute_error: 0.0603 - val_loss: 0.0071 - val_mean_absolute_error: 0.0588
# Epoch 10/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0077 - mean_absolute_error: 0.0600
# Epoch 00010: saving model to lstm_demo.10.hdf5
# 24164/24164 [==============================] - 7s 288us/sample - loss: 0.0077 - mean_absolute_error: 0.0600 - val_loss: 0.0069 - val_mean_absolute_error: 0.0584
# Epoch 11/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0076 - mean_absolute_error: 0.0597
# Epoch 00011: saving model to lstm_demo.11.hdf5
# 24164/24164 [==============================] - 7s 288us/sample - loss: 0.0076 - mean_absolute_error: 0.0597 - val_loss: 0.0069 - val_mean_absolute_error: 0.0582
# Epoch 12/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0076 - mean_absolute_error: 0.0595
# Epoch 00012: saving model to lstm_demo.12.hdf5
# 24164/24164 [==============================] - 7s 291us/sample - loss: 0.0076 - mean_absolute_error: 0.0595 - val_loss: 0.0068 - val_mean_absolute_error: 0.0586
# Epoch 13/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0076 - mean_absolute_error: 0.0595
# Epoch 00013: saving model to lstm_demo.13.hdf5
# 24164/24164 [==============================] - 7s 290us/sample - loss: 0.0076 - mean_absolute_error: 0.0595 - val_loss: 0.0069 - val_mean_absolute_error: 0.0599
# Epoch 14/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0076 - mean_absolute_error: 0.0597
# Epoch 00014: saving model to lstm_demo.14.hdf5
# 24164/24164 [==============================] - 7s 289us/sample - loss: 0.0076 - mean_absolute_error: 0.0597 - val_loss: 0.0069 - val_mean_absolute_error: 0.0607
# Epoch 15/15
# 24064/24164 [============================>.] - ETA: 0s - loss: 0.0077 - mean_absolute_error: 0.0600
# Epoch 00015: saving model to lstm_demo.15.hdf5
# 24164/24164 [==============================] - 7s 288us/sample - loss: 0.0077 - mean_absolute_error: 0.0600 - val_loss: 0.0071 - val_mean_absolute_error: 0.0627

# %%
model = tf.keras.Sequential()

model.add(layers.LSTM(
    X_train.shape[1],
    input_shape=(X_train.shape[1],X_train.shape[2]),
    return_sequences=True,
    stateful=True,
    batch_size=batch_size,
    #dropout=0.2,
    #recurrent_dropout=0.2
    ))

model.add(layers.LSTM(
    neurons,
    return_sequences=False,
    stateful=True
    #dropout=0.2,
    #recurrent_dropout=0.2
    ))

model.add(layers.Dense(neurons,activation="relu"))

model.add(layers.Dense(Y_train.shape[1]))

model.compile(loss="mse", optimizer="adam", metrics=['mae'])

print(model.summary())
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (2, 48, 48)               10752
# _________________________________________________________________
# lstm_16 (LSTM)               (2, 64)                   28928
# _________________________________________________________________
# dense_14 (Dense)             (2, 64)                   4160
# _________________________________________________________________
# dense_15 (Dense)             (2, 1)                    65
# =================================================================
# Total params: 43,905
# Trainable params: 43,905
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
print('Training')
for i in range(epochs):
    print('Epoch', i + 1, '/', epochs)
    # Note that the last state for sample i in a batch will
    # be used as initial state for sample i in the next batch.
    # Thus we are simultaneously training on batch_size series with
    # lower resolution than the original series contained in data_input.
    # Each of these series are offset by one step and can be
    # extracted with data_input[i::batch_size].
    model.fit(X_train,Y_train,batch_size=batch_size,epochs=1,verbose=1,validation_data=(X_val, Y_val),shuffle=False,workers=4)
    model.reset_states()
# Out:
# Training
# Epoch 1 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1453s 60ms/sample - loss: 0.0088 - mean_absolute_error: 0.0650 - val_loss: 0.0077 - val_mean_absolute_error: 0.0614
# Epoch 2 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1451s 60ms/sample - loss: 0.0079 - mean_absolute_error: 0.0606 - val_loss: 0.0077 - val_mean_absolute_error: 0.0604
# Epoch 3 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1450s 60ms/sample - loss: 0.0076 - mean_absolute_error: 0.0595 - val_loss: 0.0075 - val_mean_absolute_error: 0.0595
# Epoch 4 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1451s 60ms/sample - loss: 0.0074 - mean_absolute_error: 0.0587 - val_loss: 0.0074 - val_mean_absolute_error: 0.0592
# Epoch 5 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1451s 60ms/sample - loss: 0.0073 - mean_absolute_error: 0.0578 - val_loss: 0.0075 - val_mean_absolute_error: 0.0590
# Epoch 6 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1452s 60ms/sample - loss: 0.0071 - mean_absolute_error: 0.0571 - val_loss: 0.0072 - val_mean_absolute_error: 0.0579
# Epoch 7 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1452s 60ms/sample - loss: 0.0070 - mean_absolute_error: 0.0565 - val_loss: 0.0073 - val_mean_absolute_error: 0.0582
# Epoch 8 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1453s 60ms/sample - loss: 0.0068 - mean_absolute_error: 0.0559 - val_loss: 0.0075 - val_mean_absolute_error: 0.0585
# Epoch 9 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1453s 60ms/sample - loss: 0.0067 - mean_absolute_error: 0.0551 - val_loss: 0.0072 - val_mean_absolute_error: 0.0579
# Epoch 10 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1455s 60ms/sample - loss: 0.0066 - mean_absolute_error: 0.0546 - val_loss: 0.0073 - val_mean_absolute_error: 0.0579
# Epoch 11 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1459s 60ms/sample - loss: 0.0065 - mean_absolute_error: 0.0540 - val_loss: 0.0071 - val_mean_absolute_error: 0.0569
# Epoch 12 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1455s 60ms/sample - loss: 0.0063 - mean_absolute_error: 0.0535 - val_loss: 0.0070 - val_mean_absolute_error: 0.0563
# Epoch 13 / 15
# Train on 24164 samples, validate on 6870 samples
# 24164/24164 [==============================] - 1456s 60ms/sample - loss: 0.0063 - mean_absolute_error: 0.0531 - val_loss: 0.0070 - val_mean_absolute_error: 0.0563
# Epoch 14 / 15
# Train on 24164 samples, validate on 6870 samples
#  4440/24164 [====>.........................] - ETA: 18:06 - loss: 0.0074 - mean_absolute_error: 0.0590

# %%
X_train.shape
X_val.shape
# Out:
# (6870, 48, 7)

# %%
plt.plot(lstm_history.history['loss'])
plt.plot(lstm_history.history['val_loss'])
plt.ylabel('Loss - MSE')
plt.xlabel('epoch')
plt.title('Training vs Val Performance')
plt.grid()

# %%
# Save entire model to a HDF5 file
model.save('my_model')

# %%
# save a json
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")

# %%
# Recreate the exact same model, including weights and optimizer.
model = tf.keras.models.load_model('my_model')

# %% [markdown]
# # Evaluation

# %%
print('Predicting')
# Out:
# Predicting

# %%
y_hat = model.predict(X_test[:3410,:,:])

# %%
# mse
from sklearn.metrics import mean_squared_error
mse_test = mean_squared_error(Y_test[:3410,:],y_hat)

# %%
mse_test
# Out:
# 0.005747004456023808

# %%
# check
model.evaluate(X_test[:3410,:,:], Y_test[:3410,:], batch_size=batch_size)
# Out:
# 3410/3410 [==============================] - 60s 17ms/sample - loss: 0.0057 - mean_absolute_error: 0.0551
# [0.005746976087560845, 0.055078134]

# %%
from datetime import datetime
tt = [datetime.strptime(x, '%Y-%m-%d %H:%M:%S') for x in test_scaled_df.index.values]

# %%
len(tt[48:-1])
# Out:
# 3410

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.plot(tt, y)
plt.plot(tt[48:-1],y_hat)
fig.autofmt_xdate()
#ax.set_xlim([datetime.date(2014, 1, 26), datetime.date(2014, 2, 1)])
#ax.set_ylim([0, 5])

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.plot(tt, y)
plt.plot(tt[48:-1],y_hat)
fig.autofmt_xdate()
ax.set_xlim([datetime(2010, 7, 17), datetime(2010, 7, 31)])
plt.legend(['actual','prediction'])
plt.grid()
#ax.set_ylim([0, 5])

# %% [markdown]
# # Deployment

# %%
from tensorflow.python.saved_model import builder
from tensorflow.python.saved_model.signature_def_utils import predict_signature_def
from tensorflow.python.saved_model import tag_constants

# %%
model_version = '1'
export_dir = 'export/Servo/' + model_version

# Build the Protocol Buffer SavedModel at 'export_dir'
builder = builder.save(export_dir)

# Create prediction signature to be used by TensorFlow Serving Predict API
signature = predict_signature_def(
    inputs={"inputs": model.input}, outputs={"score": model.output})

from keras import backend as K

with K.get_session() as sess:
    # Save the meta graph and variables
    builder.add_meta_graph_and_variables(
        sess=sess, tags=[tag_constants.SERVING], signature_def_map={"serving_default": signature})
    builder.save()

# %%
builder

# %%
import tarfile
with tarfile.open('model.tar.gz', mode='w:gz') as archive:
    archive.add('export', recursive=True)

import sagemaker

sagemaker_session = sagemaker.Session()
inputs = sagemaker_session.upload_data(path='model.tar.gz', key_prefix='model')

# %%
model.input
# Out:
# <tf.Tensor 'lstm_input_1:0' shape=(?, 48, 7) dtype=float32>
