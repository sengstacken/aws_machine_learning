# %% [markdown]
# Dataset size:
#
# * Training Dataset - input: (1567893, 75), output: (1567893,)
# * Validation Dataset - input: (174211, 75), output: (174211,)

# %%
import sagemaker
import os
import boto3
import sys
import pandas as pd
from IPython.core.display import display, HTML
from sagemaker.tensorflow import TensorFlow
from sagemaker.debugger import Rule, rule_configs, ProfilerConfig, ProfilerRule, FrameworkProfile, DetailedProfilingConfig, DataloaderProfilingConfig, PythonProfilingConfig, PythonProfiler, cProfileTimer, CollectionConfig, DebuggerHookConfig

# %%
region = boto3.Session().region_name
role = sagemaker.get_execution_role()
sagemaker_session = sagemaker.Session()
bucket_name = sagemaker.Session().default_bucket()

prefix = 'ipinyou-tf'
os.environ["AWS_REGION"] = region

print(f'Region:  {region}')
print(f'IAM Role:  {role}')
print(f'S3 Bucket:  {bucket_name}')

# Get the current installed version of Sagemaker SDK, TensorFlow, Python, Boto3 and SMDebug
print(f'SageMaker Python SDK version:  {sagemaker.__version__}')
#print(f'TensorFlow version : {tf.__version__}')
print(f'Python version:  {sys.version}')
print(f'Boto3 version : {boto3.__version__}')
print(f'Pandas Version:  {pd.__version__}')
# Out:
# Region:  us-east-1
# IAM Role:  arn:aws:iam::431615879134:role/sagemaker-test-role
# S3 Bucket:  sagemaker-us-east-1-431615879134
# SageMaker Python SDK version:  2.99.0
# Python version:  3.7.10 (default, Jun  4 2021, 14:48:32)
# [GCC 7.5.0]
# Boto3 version : 1.24.27
# Pandas Version:  1.3.5

# %%
def call_training(config):
    print(config)
    
    # configure debugger
    rules=[
        ProfilerRule.sagemaker(rule_configs.ProfilerReport()),
        Rule.sagemaker(rule_configs.loss_not_decreasing()),
        Rule.sagemaker(rule_configs.overfit()),
        Rule.sagemaker(rule_configs.overtraining()),
        Rule.sagemaker(
            base_config=rule_configs.stalled_training_rule(),
            rule_parameters={
                    "threshold": "1800",
                    "stop_training_on_fire": "True",
                    "training_job_name_prefix": config['job_name']
            },
            collections_to_save=[ 
                CollectionConfig(
                    name="losses", 
                    parameters={
                        "save_interval": "500"
                    } 
                )
            ]
        )
    ]
    debugger_hook_config = DebuggerHookConfig(
        hook_parameters={"save_interval":"2000"}, # steps
        collection_configs=[
            CollectionConfig(name="inputs"),
            CollectionConfig(name="outputs"),
            CollectionConfig(name="layers"),
            CollectionConfig(name="gradients")
        ])
    
    profiler_config = ProfilerConfig(
        system_monitor_interval_millis=200,
        framework_profile_params=FrameworkProfile()
    )
    
    # configure input data
    if config['data_type'].lower() == 'csv':
        
        # single CSV File
        s3_input_train = sagemaker.inputs.TrainingInput(s3_data=f's3://{bucket_name}/{prefix}/data/train', content_type='csv', distribution='ShardedByS3Key')
        s3_input_test = sagemaker.inputs.TrainingInput(s3_data=f's3://{bucket_name}/{prefix}/data/test', content_type='csv', distribution='ShardedByS3Key')
        
    elif config['data_type'].lower() == 'parquet':
        
        # group of parquet files
        s3_input_train = sagemaker.inputs.TrainingInput(s3_data=f's3://sagemaker-us-east-1-431615879134/ipinyou-tf/data/parquet_train/', distribution='ShardedByS3Key')
        s3_input_test = sagemaker.inputs.TrainingInput(s3_data=f's3://sagemaker-us-east-1-431615879134/ipinyou-tf/data/parquet_test/', distribution='ShardedByS3Key')
        
    elif config['data_type'].lower() == 'tfrecord':
        
        # group of tfrecord files
        s3_input_train = sagemaker.inputs.TrainingInput(s3_data=f's3://{bucket_name}/{prefix}/data/train_tfr', distribution='ShardedByS3Key')
        s3_input_test = sagemaker.inputs.TrainingInput(s3_data=f's3://{bucket_name}/{prefix}/data/test_tfr', distribution='ShardedByS3Key')
    
    elif config['data_type'].lower() == 'parquetffm':
        
        # group of parquet files
        s3_input_train = sagemaker.inputs.TrainingInput(s3_data=f's3://sagemaker-us-east-1-431615879134/ipinyou-tf/data/parquet_train/', distribution='ShardedByS3Key', input_mode='FastFile')
        s3_input_test = sagemaker.inputs.TrainingInput(s3_data=f's3://sagemaker-us-east-1-431615879134/ipinyou-tf/data/parquet_test/', distribution='ShardedByS3Key', input_mode='FastFile')
        
    elif config['data_type'].lower() == 'tfrecordffm':
        
        # group of tfrecord files
        s3_input_train = sagemaker.inputs.TrainingInput(s3_data=f's3://{bucket_name}/{prefix}/data/train_tfr', distribution='ShardedByS3Key', input_mode='FastFile')
        s3_input_test = sagemaker.inputs.TrainingInput(s3_data=f's3://{bucket_name}/{prefix}/data/test_tfr', distribution='ShardedByS3Key', input_mode='FastFile')
    
    else:
        print('Unknown datatype specified')
        
    # specify hyper parameters
    hyperparameters = {'epochs': 5,
                       'batchsize': config['batchsize'],
                       'lr': 4e-3
                      }
    
    # call training job
    estimator = TensorFlow(
        base_job_name=config['job_name'],
        source_dir="code",
        entry_point=config['code'],
        role=role,
        py_version="py37",
        framework_version="2.3.1",
        instance_count=1,
        instance_type=config['compute'],
        sagemaker_session=sagemaker_session,
        profiler_config=profiler_config,
        rules=rules,
        debugger_hook_config=debugger_hook_config,
        hyperparameters=hyperparameters
)
    estimator.fit({'train': s3_input_train, 'validation': s3_input_test})
    print(estimator.latest_training_job.job_name)
    return estimator.latest_training_job.job_name

# %% [markdown]
# ## Training with CSV

# %%
training_config = [
    {
        'job_name':'ipinyou-csv-m52xl-inmem2048',
        'compute':'ml.m5.2xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv_inmem.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-csv-c42xl-inmem2048',
        'compute':'ml.c4.2xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv_inmem.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-csv-g4dnxl-inmem2048',
        'compute':'ml.g4dn.xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv_inmem.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-csv-p32xl-inmem2048',
        'compute':'ml.p3.2xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv_inmem.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-csv-m52xl-inmem4096',
        'compute':'ml.m5.2xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv_inmem.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-csv-c42xl-inmem4096',
        'compute':'ml.c4.2xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv_inmem.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-csv-g4dnxl-inmem4096',
        'compute':'ml.g4dn.xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv_inmem.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-csv-p32xl-inmem4096',
        'compute':'ml.p3.2xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv_inmem.py',
        'batchsize':4096,
    }, 
    
     {
        'job_name':'ipinyou-csvdl-m52xl-inmem2048',
        'compute':'ml.m5.2xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-csvdl-c42xl-inmem2048',
        'compute':'ml.c4.2xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-csvdl-g4dnxl-inmem2048',
        'compute':'ml.g4dn.xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-csvdl-p32xl-inmem2048',
        'compute':'ml.p3.2xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-csvdl-m52xl-inmem4096',
        'compute':'ml.m5.2xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-csvdl-c42xl-inmem4096',
        'compute':'ml.c4.2xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-csvdl-g4dnxl-inmem4096',
        'compute':'ml.g4dn.xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-csvdl-p32xl-inmem4096',
        'compute':'ml.p3.2xlarge',
        'data_type':'csv',
        'code':'tf_profile_fit_csv.py',
        'batchsize':4096,
    }, 
    
]

# %% [markdown]
# Note - Each training jobs will run sequential

# %%
namelist = []
for train in training_config:
    name = call_training(train)
    namelist.append(name)
# Out:
# {'job_name': 'ipinyou-csv-m52xl-inmem2048', 'compute': 'ml.m5.2xlarge', 'data_type': 'csv', 'code': 'tf_profile_fit_csv_inmem.py', 'batchsize': 2048}
# 2022-08-13 18:15:53 Starting - Starting the training job...
# 2022-08-13 18:16:18 Starting - Preparing the instances for trainingLossNotDecreasing: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# StalledTrainingRule: InProgress
# ProfilerReport: InProgress
# .........
# 2022-08-13 18:17:45 Downloading - Downloading input data
# 2022-08-13 18:17:45 Training - Downloading the training image...
# 2022-08-13 18:18:18 Training - Training image download completed. Training in progress.2022-08-13 18:18:13.323088: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-13 18:18:13.327750: I tensorflow/core/profiler/internal/smprofiler_config_reader.cc:123] PID of the process that is writing to the timeline : 1
# 2022-08-13 18:18:13.328443: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:121] SageMaker Profiler Timeline Writer read the following config parameters :
# 2022-08-13 18:18:13.328461: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:122] Base Folder : /opt/ml/output/profiler
# 2022-08-13 18:18:13.328466: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:123] Node Id : 1-algo-1
# 2022-08-13 18:18:13.328471: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:124] Maximum file size : 10485760
# 2022-08-13 18:18:13.328475: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:125] Close file interval : 60
# 2022-08-13 18:18:13.328479: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:126] Continuous fail count threshold : 50
# 2022-08-13 18:18:13.328485: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:144] PID of the current Timeline Process : 1
# 2022-08-13 18:18:13.540366: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-13 18:18:16,867 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-08-13 18:18:16,875 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-13 18:18:17,384 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-13 18:18:17,402 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-13 18:18:17,418 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-13 18:18:17,429 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batchsize": 2048,
#         "epochs": 5,
#         "lr": 0.004,
#         "model_dir": "s3://sagemaker-us-east-1-431615879134/ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "ContentType": "csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "ContentType": "csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-431615879134/ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329/source/sourcedir.tar.gz",
#     "module_name": "tf_profile_fit_csv_inmem",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "tf_profile_fit_csv_inmem.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batchsize":2048,"epochs":5,"lr":0.004,"model_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329/model"}
# SM_USER_ENTRY_POINT=tf_profile_fit_csv_inmem.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"validation":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=tf_profile_fit_csv_inmem
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batchsize":2048,"epochs":5,"lr":0.004,"model_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"validation":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329/source/sourcedir.tar.gz","module_name":"tf_profile_fit_csv_inmem","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"tf_profile_fit_csv_inmem.py"}
# SM_USER_ARGS=["--batchsize","2048","--epochs","5","--lr","0.004","--model_dir","s3://sagemaker-us-east-1-431615879134/ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_BATCHSIZE=2048
# SM_HP_EPOCHS=5
# SM_HP_LR=0.004
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 tf_profile_fit_csv_inmem.py --batchsize 2048 --epochs 5 --lr 0.004 --model_dir s3://sagemaker-us-east-1-431615879134/ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329/model
# [2022-08-13 18:18:19.537 ip-10-0-181-230.ec2.internal:34 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-08-13 18:18:19.806 ip-10-0-181-230.ec2.internal:34 INFO profiler_config_parser.py:102] Using config at /opt/ml/input/config/profilerconfig.json.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               9728
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 42,881
# Trainable params: 42,881
# Non-trainable params: 0
# _________________________________________________________________
# [2022-08-13 18:18:36.295 ip-10-0-181-230.ec2.internal:34 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-08-13 18:18:36.298 ip-10-0-181-230.ec2.internal:34 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-08-13 18:18:36.299 ip-10-0-181-230.ec2.internal:34 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2022-08-13 18:18:36.300 ip-10-0-181-230.ec2.internal:34 INFO state_store.py:75] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-08-13 18:18:37.255 ip-10-0-181-230.ec2.internal:34 INFO hook.py:413] Monitoring the collections: gradients, metrics, sm_metrics, inputs, losses, layers, outputs
# Epoch 1/5
# [2022-08-13 18:18:37.357 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/prestepzero-*-start-1660414699806734.0_train-0-stepstart-1660414717356955.2/python_stats.
# [2022-08-13 18:18:38.755 ip-10-0-181-230.ec2.internal:34 INFO keras.py:911] Enabling TF profiler on step: = 5
# [2022-08-13 18:18:38.784 ip-10-0-181-230.ec2.internal:34 INFO keras.py:922] Disabling TF profiler on step: =6
# [2022-08-13 18:18:38.944 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-9-stepstart-1660414718901912.0_train-9-stepend-1660414718944071.5/python_stats.
# [2022-08-13 18:18:38.949 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-9-stepend-1660414718947695.2_train-10-stepstart-1660414718949638.8/python_stats.
# [2022-08-13 18:18:39.020 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-10-stepstart-1660414718951281.0_train-10-stepend-1660414719020123.5/python_stats.
# [2022-08-13 18:18:39.035 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-10-stepend-1660414719023156.8_train-11-stepstart-1660414719034891.0/python_stats.
# [2022-08-13 18:18:39.091 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-11-stepstart-1660414719036726.8_train-11-stepend-1660414719091160.0/python_stats.
# [2022-08-13 18:18:39.095 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-11-stepend-1660414719093905.8_train-12-stepstart-1660414719095514.0/python_stats.
# [2022-08-13 18:18:59.320 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-9-stepstart-1660414739298357.2_eval-9-stepend-1660414739320085.8/python_stats.
# [2022-08-13 18:18:59.323 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-9-stepend-1660414739322457.2_eval-10-stepstart-1660414739323664.2/python_stats.
# [2022-08-13 18:18:59.347 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-10-stepstart-1660414739324814.2_eval-10-stepend-1660414739347517.8/python_stats.
# [2022-08-13 18:18:59.352 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-10-stepend-1660414739350202.2_eval-11-stepstart-1660414739351850.2/python_stats.
# [2022-08-13 18:18:59.378 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-11-stepstart-1660414739353433.2_eval-11-stepend-1660414739378349.0/python_stats.
# [2022-08-13 18:18:59.382 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-11-stepend-1660414739380532.8_eval-12-stepstart-1660414739381849.5/python_stats.
# 766/766 - 21s - loss: 0.1472 - accuracy: 0.9984 - val_loss: 0.0072 - val_accuracy: 0.9992 - batch: 0.0000e+00
# Epoch 2/5
# [2022-08-13 18:19:00.065 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-85-stepend-1660414740046120.5_train-766-stepstart-1660414740064816.5/python_stats.
# 766/766 - 23s - loss: 0.0087 - accuracy: 0.9992 - val_loss: 0.0065 - val_accuracy: 0.9992 - batch: 1.0000
# Epoch 3/5
# [2022-08-13 18:19:23.452 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-171-stepend-1660414763427635.5_train-1532-stepstart-1660414763452606.0/python_stats.
# 766/766 - 21s - loss: 0.0083 - accuracy: 0.9992 - val_loss: 0.0097 - val_accuracy: 0.9992 - batch: 2.0000
# Epoch 4/5
# [2022-08-13 18:19:44.251 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-257-stepend-1660414784233411.8_train-2298-stepstart-1660414784250804.2/python_stats.
# 766/766 - 24s - loss: 0.0080 - accuracy: 0.9992 - val_loss: 0.0070 - val_accuracy: 0.9992 - batch: 3.0000
# Epoch 5/5
# [2022-08-13 18:20:07.801 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-343-stepend-1660414807783621.2_train-3064-stepstart-1660414807801272.8/python_stats.
# 766/766 - 21s - loss: 0.0075 - accuracy: 0.9992 - val_loss: 0.0083 - val_accuracy: 0.9992 - batch: 4.0000
# [2022-08-13 18:20:29.147 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-429-stepend-1660414829126608.2_train-3829-stepend-1660414829146782.2/python_stats.
# [2022-08-13 18:20:29.445 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-3829-stepend-1660414829151230.5_eval-430-stepstart-1660414829445358.8/python_stats.
# 5445/5445 - 42s - loss: 0.0083 - accuracy: 0.9992
#
# 2022-08-13 18:21:26 Uploading - Uploading generated training model[2022-08-13 18:21:19.701 ip-10-0-181-230.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-5874-stepend-1660414871523338.2_posthookclose-*-end-1660414879697254.5/python_stats.
# 2022-08-13 18:18:17.992333: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-13 18:18:18.026693: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# INFO:__main__:Executing the main() function...
# INFO:__main__:TensorFlow version : 2.3.1
# INFO:__main__:Parsing command-line arguments...
# INFO:__main__:Completed parsing command-line arguments.
# INFO:__main__:Namespace(batchsize=2048, checkpoint_enabled='False', checkpoint_load_previous='False', checkpoint_local_dir='/opt/ml/checkpoints/', epochs=5, lr=0.004, model_dir='s3://sagemaker-us-east-1-431615879134/ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329/model', seed=42, train_dir='/opt/ml/input/data/train', val_dir='/opt/ml/input/data/validation')
# INFO:__main__:Files in /opt/ml/input/data/train: ['/opt/ml/input/data/train/train.csv']
# INFO:__main__:Data loaded from /opt/ml/input/data/train, shapes, input: (1567893, 75), output: (1567893,)
# INFO:__main__:Completed loading and preprocessing data.
# INFO:__main__:Files in /opt/ml/input/data/validation: ['/opt/ml/input/data/validation/test.csv']
# INFO:__main__:Data loaded from /opt/ml/input/data/validation, shapes, input: (174211, 75), output: (174211,)
# INFO:__main__:Completed loading and preprocessing data.
# INFO:__main__:Creating the model...
# INFO:__main__:None
# INFO:__main__:Completed creating the model.
# INFO:__main__:Compiling the model...
# INFO:__main__:Completed compiling the model.
# INFO:__main__:Training the model...
# INFO:__main__:Checkpointing will not be performed.
# INFO:__main__:Training duration = 112.87 seconds
# INFO:__main__:Completed training the model.
# INFO:__main__:Evaluating the model...
# INFO:__main__:Test loss = 0.008336340077221394
# INFO:__main__:Test accuracy = 0.9992193579673767
# INFO:__main__:Completed evaluating the model.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2022-08-13 18:21:12.919346: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: s3://sagemaker-us-east-1-431615879134/ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329/model/000000001/assets
# INFO:tensorflow:Assets written to: s3://sagemaker-us-east-1-431615879134/ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329/model/000000001/assets
# INFO:__main__:Completed executing the main() function.
# 2022-08-13 18:21:20,158 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2022-08-13 18:21:20,158 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2022-08-13 18:21:59 Completed - Training job completed
# ProfilerReport: IssuesFound
# Training seconds: 248
# Billable seconds: 248
# ipinyou-csv-m52xl-inmem2048-2022-08-13-18-15-53-329
# {'job_name': 'ipinyou-csv-c42xl-inmem2048', 'compute': 'ml.c4.2xlarge', 'data_type': 'csv', 'code': 'tf_profile_fit_csv_inmem.py', 'batchsize': 2048}
# 2022-08-13 18:22:13 Starting - Starting the training job...
# 2022-08-13 18:22:43 Starting - Preparing the instances for trainingLossNotDecreasing: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# StalledTrainingRule: InProgress
# ProfilerReport: InProgress
# ......
# 2022-08-13 18:23:44 Downloading - Downloading input data...
# 2022-08-13 18:24:14 Training - Downloading the training image...
# 2022-08-13 18:24:43 Training - Training image download completed. Training in progress..2022-08-13 18:24:43.103215: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-13 18:24:43.114640: I tensorflow/core/profiler/internal/smprofiler_config_reader.cc:123] PID of the process that is writing to the timeline : 1
# 2022-08-13 18:24:43.116508: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:121] SageMaker Profiler Timeline Writer read the following config parameters :
# 2022-08-13 18:24:43.116530: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:122] Base Folder : /opt/ml/output/profiler
# 2022-08-13 18:24:43.116541: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:123] Node Id : 1-algo-1
# 2022-08-13 18:24:43.116551: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:124] Maximum file size : 10485760
# 2022-08-13 18:24:43.116559: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:125] Close file interval : 60
# 2022-08-13 18:24:43.116568: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:126] Continuous fail count threshold : 50
# 2022-08-13 18:24:43.116580: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:144] PID of the current Timeline Process : 1
# 2022-08-13 18:24:43.469015: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-13 18:24:47,078 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-08-13 18:24:47,085 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-13 18:24:47,584 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-13 18:24:47,604 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-13 18:24:47,619 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-13 18:24:47,634 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batchsize": 2048,
#         "epochs": 5,
#         "lr": 0.004,
#         "model_dir": "s3://sagemaker-us-east-1-431615879134/ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "ContentType": "csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "ContentType": "csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-431615879134/ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447/source/sourcedir.tar.gz",
#     "module_name": "tf_profile_fit_csv_inmem",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.c4.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.c4.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "tf_profile_fit_csv_inmem.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batchsize":2048,"epochs":5,"lr":0.004,"model_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447/model"}
# SM_USER_ENTRY_POINT=tf_profile_fit_csv_inmem.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c4.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c4.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"validation":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=tf_profile_fit_csv_inmem
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batchsize":2048,"epochs":5,"lr":0.004,"model_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"validation":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447/source/sourcedir.tar.gz","module_name":"tf_profile_fit_csv_inmem","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c4.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c4.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"tf_profile_fit_csv_inmem.py"}
# SM_USER_ARGS=["--batchsize","2048","--epochs","5","--lr","0.004","--model_dir","s3://sagemaker-us-east-1-431615879134/ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_BATCHSIZE=2048
# SM_HP_EPOCHS=5
# SM_HP_LR=0.004
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 tf_profile_fit_csv_inmem.py --batchsize 2048 --epochs 5 --lr 0.004 --model_dir s3://sagemaker-us-east-1-431615879134/ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447/model
# [2022-08-13 18:24:49.855 ip-10-2-65-147.ec2.internal:34 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-08-13 18:24:50.275 ip-10-2-65-147.ec2.internal:34 INFO profiler_config_parser.py:102] Using config at /opt/ml/input/config/profilerconfig.json.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               9728
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 42,881
# Trainable params: 42,881
# Non-trainable params: 0
# _________________________________________________________________
# [2022-08-13 18:25:07.563 ip-10-2-65-147.ec2.internal:34 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-08-13 18:25:07.565 ip-10-2-65-147.ec2.internal:34 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-08-13 18:25:07.567 ip-10-2-65-147.ec2.internal:34 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2022-08-13 18:25:07.567 ip-10-2-65-147.ec2.internal:34 INFO state_store.py:75] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-08-13 18:25:08.518 ip-10-2-65-147.ec2.internal:34 INFO hook.py:413] Monitoring the collections: gradients, outputs, inputs, sm_metrics, losses, metrics, layers
# Epoch 1/5
# [2022-08-13 18:25:08.637 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/prestepzero-*-start-1660415090276316.2_train-0-stepstart-1660415108636551.8/python_stats.
# [2022-08-13 18:25:10.159 ip-10-2-65-147.ec2.internal:34 INFO keras.py:911] Enabling TF profiler on step: = 5
# [2022-08-13 18:25:10.201 ip-10-2-65-147.ec2.internal:34 INFO keras.py:922] Disabling TF profiler on step: =6
# [2022-08-13 18:25:10.417 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-9-stepstart-1660415110367732.0_train-9-stepend-1660415110416564.8/python_stats.
# [2022-08-13 18:25:10.421 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-9-stepend-1660415110419227.0_train-10-stepstart-1660415110420859.2/python_stats.
# [2022-08-13 18:25:10.478 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-10-stepstart-1660415110422177.2_train-10-stepend-1660415110478129.5/python_stats.
# [2022-08-13 18:25:10.485 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-10-stepend-1660415110482350.8_train-11-stepstart-1660415110484756.2/python_stats.
# [2022-08-13 18:25:10.535 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-11-stepstart-1660415110486617.5_train-11-stepend-1660415110535211.2/python_stats.
# [2022-08-13 18:25:10.540 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-11-stepend-1660415110538458.8_train-12-stepstart-1660415110540605.0/python_stats.
# [2022-08-13 18:25:35.049 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-9-stepstart-1660415135020581.0_eval-9-stepend-1660415135049207.5/python_stats.
# [2022-08-13 18:25:35.054 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-9-stepend-1660415135052278.0_eval-10-stepstart-1660415135054594.0/python_stats.
# [2022-08-13 18:25:35.094 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-10-stepstart-1660415135056426.5_eval-10-stepend-1660415135094194.5/python_stats.
# [2022-08-13 18:25:35.100 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-10-stepend-1660415135098005.2_eval-11-stepstart-1660415135100367.8/python_stats.
# [2022-08-13 18:25:35.137 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-11-stepstart-1660415135102251.2_eval-11-stepend-1660415135136641.8/python_stats.
# [2022-08-13 18:25:35.142 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-11-stepend-1660415135140198.5_eval-12-stepstart-1660415135142413.0/python_stats.
# 766/766 - 26s - loss: 0.1471 - accuracy: 0.9984 - val_loss: 0.0071 - val_accuracy: 0.9992 - batch: 0.0000e+00
# Epoch 2/5
# [2022-08-13 18:25:36.156 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-85-stepend-1660415136128791.5_train-766-stepstart-1660415136156487.8/python_stats.
# 766/766 - 27s - loss: 0.0088 - accuracy: 0.9992 - val_loss: 0.0065 - val_accuracy: 0.9992 - batch: 1.0000
# Epoch 3/5
# [2022-08-13 18:26:03.076 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-171-stepend-1660415163052865.0_train-1532-stepstart-1660415163076444.8/python_stats.
# 766/766 - 27s - loss: 0.0083 - accuracy: 0.9992 - val_loss: 0.0082 - val_accuracy: 0.9992 - batch: 2.0000
# Epoch 4/5
# [2022-08-13 18:26:30.398 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-257-stepend-1660415190372047.0_train-2298-stepstart-1660415190397855.8/python_stats.
# 766/766 - 25s - loss: 0.0081 - accuracy: 0.9992 - val_loss: 0.0073 - val_accuracy: 0.9992 - batch: 3.0000
# Epoch 5/5
# [2022-08-13 18:26:55.450 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-343-stepend-1660415215428474.0_train-3064-stepstart-1660415215450428.0/python_stats.
# 766/766 - 26s - loss: 0.0076 - accuracy: 0.9992 - val_loss: 0.0080 - val_accuracy: 0.9992 - batch: 4.0000
# [2022-08-13 18:27:21.914 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-429-stepend-1660415241896367.0_train-3829-stepend-1660415241914386.5/python_stats.
# [2022-08-13 18:27:22.144 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-3829-stepend-1660415241917285.2_eval-430-stepstart-1660415242143849.5/python_stats.
# 5445/5445 - 47s - loss: 0.0080 - accuracy: 0.9992
# [2022-08-13 18:28:19.717 ip-10-2-65-147.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-5874-stepend-1660415289282177.5_posthookclose-*-end-1660415299715269.8/python_stats.
# 2022-08-13 18:24:48.139954: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-13 18:24:48.170360: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# INFO:__main__:Executing the main() function...
# INFO:__main__:TensorFlow version : 2.3.1
# INFO:__main__:Parsing command-line arguments...
# INFO:__main__:Completed parsing command-line arguments.
# INFO:__main__:Namespace(batchsize=2048, checkpoint_enabled='False', checkpoint_load_previous='False', checkpoint_local_dir='/opt/ml/checkpoints/', epochs=5, lr=0.004, model_dir='s3://sagemaker-us-east-1-431615879134/ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447/model', seed=42, train_dir='/opt/ml/input/data/train', val_dir='/opt/ml/input/data/validation')
# INFO:__main__:Files in /opt/ml/input/data/train: ['/opt/ml/input/data/train/train.csv']
# INFO:__main__:Data loaded from /opt/ml/input/data/train, shapes, input: (1567893, 75), output: (1567893,)
# INFO:__main__:Completed loading and preprocessing data.
# INFO:__main__:Files in /opt/ml/input/data/validation: ['/opt/ml/input/data/validation/test.csv']
# INFO:__main__:Data loaded from /opt/ml/input/data/validation, shapes, input: (174211, 75), output: (174211,)
# INFO:__main__:Completed loading and preprocessing data.
# INFO:__main__:Creating the model...
# INFO:__main__:None
# INFO:__main__:Completed creating the model.
# INFO:__main__:Compiling the model...
# INFO:__main__:Completed compiling the model.
# INFO:__main__:Training the model...
# INFO:__main__:Checkpointing will not be performed.
# INFO:__main__:Training duration = 134.36 seconds
# INFO:__main__:Completed training the model.
# INFO:__main__:Evaluating the model...
# INFO:__main__:Test loss = 0.008035233244299889
# INFO:__main__:Test accuracy = 0.9992193579673767
# INFO:__main__:Completed evaluating the model.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2022-08-13 18:28:20,381 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2022-08-13 18:28:11.056518: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# 2022-08-13 18:28:20,381 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: s3://sagemaker-us-east-1-431615879134/ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447/model/000000001/assets
# INFO:tensorflow:Assets written to: s3://sagemaker-us-east-1-431615879134/ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447/model/000000001/assets
# INFO:__main__:Completed executing the main() function.
#
# 2022-08-13 18:28:45 Uploading - Uploading generated training model
# 2022-08-13 18:28:45 Completed - Training job completed
# ProfilerReport: IssuesFound
# Training seconds: 282
# Billable seconds: 282
# ipinyou-csv-c42xl-inmem2048-2022-08-13-18-22-13-447
# {'job_name': 'ipinyou-csv-g4dnxl-inmem2048', 'compute': 'ml.g4dn.xlarge', 'data_type': 'csv', 'code': 'tf_profile_fit_csv_inmem.py', 'batchsize': 2048}
# 2022-08-13 18:29:02 Starting - Starting the training job...
# 2022-08-13 18:29:26 Starting - Preparing the instances for trainingLossNotDecreasing: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# StalledTrainingRule: InProgress
# ProfilerReport: InProgress
# .........
# 2022-08-13 18:31:00 Downloading - Downloading input data
# 2022-08-13 18:31:00 Training - Downloading the training image..............2022-08-13 18:33:10.221740: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-13 18:33:10.226490: I tensorflow/core/profiler/internal/smprofiler_config_reader.cc:123] PID of the process that is writing to the timeline : 1
# 2022-08-13 18:33:10.226987: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:121] SageMaker Profiler Timeline Writer read the following config parameters :
# 2022-08-13 18:33:10.227011: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:122] Base Folder : /opt/ml/output/profiler
# 2022-08-13 18:33:10.227017: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:123] Node Id : 1-algo-1
# 2022-08-13 18:33:10.227026: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:124] Maximum file size : 10485760
# 2022-08-13 18:33:10.227032: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:125] Close file interval : 60
# 2022-08-13 18:33:10.227037: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:126] Continuous fail count threshold : 50
# 2022-08-13 18:33:10.227047: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:144] PID of the current Timeline Process : 1
# 2022-08-13 18:33:10.423864: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2022-08-13 18:33:10.516457: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-13 18:33:14,269 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-08-13 18:33:14,967 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batchsize": 2048,
#         "epochs": 5,
#         "lr": 0.004,
#         "model_dir": "s3://sagemaker-us-east-1-431615879134/ipinyou-csv-g4dnxl-inmem2048-2022-08-13-18-29-02-415/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "ContentType": "csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "ContentType": "csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "ipinyou-csv-g4dnxl-inmem2048-2022-08-13-18-29-02-415",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-431615879134/ipinyou-csv-g4dnxl-inmem2048-2022-08-13-18-29-02-415/source/sourcedir.tar.gz",
#     "module_name": "tf_profile_fit_csv_inmem",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g4dn.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g4dn.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "tf_profile_fit_csv_inmem.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batchsize":2048,"epochs":5,"lr":0.004,"model_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-csv-g4dnxl-inmem2048-2022-08-13-18-29-02-415/model"}
# SM_USER_ENTRY_POINT=tf_profile_fit_csv_inmem.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.xlarge"}],"network_interface_name":"eth0"}
# ...
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=tf_profile_fit_csv
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-csvdl-p32xl-inmem4096-2022-08-13-19-53-19-648/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batchsize":4096,"epochs":5,"lr":0.004,"model_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-csvdl-p32xl-inmem4096-2022-08-13-19-53-19-648/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"validation":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"ipinyou-csvdl-p32xl-inmem4096-2022-08-13-19-53-19-648","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-csvdl-p32xl-inmem4096-2022-08-13-19-53-19-648/source/sourcedir.tar.gz","module_name":"tf_profile_fit_csv","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"tf_profile_fit_csv.py"}
# SM_USER_ARGS=["--batchsize","4096","--epochs","5","--lr","0.004","--model_dir","s3://sagemaker-us-east-1-431615879134/ipinyou-csvdl-p32xl-inmem4096-2022-08-13-19-53-19-648/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_BATCHSIZE=4096
# SM_HP_EPOCHS=5
# SM_HP_LR=0.004
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-csvdl-p32xl-inmem4096-2022-08-13-19-53-19-648/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 tf_profile_fit_csv.py --batchsize 4096 --epochs 5 --lr 0.004 --model_dir s3://sagemaker-us-east-1-431615879134/ipinyou-csvdl-p32xl-inmem4096-2022-08-13-19-53-19-648/model
# [2022-08-13 19:57:48.850 ip-10-0-238-49.ec2.internal:34 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-08-13 19:57:49.265 ip-10-0-238-49.ec2.internal:34 INFO profiler_config_parser.py:102] Using config at /opt/ml/input/config/profilerconfig.json.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               9728
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 42,881
# Trainable params: 42,881
# Non-trainable params: 0
# _________________________________________________________________
# [2022-08-13 19:58:17.280 ip-10-0-238-49.ec2.internal:34 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-08-13 19:58:17.284 ip-10-0-238-49.ec2.internal:34 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-08-13 19:58:17.287 ip-10-0-238-49.ec2.internal:34 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2022-08-13 19:58:17.288 ip-10-0-238-49.ec2.internal:34 INFO state_store.py:75] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-08-13 19:58:17.342 ip-10-0-238-49.ec2.internal:34 INFO hook.py:413] Monitoring the collections: gradients, losses, metrics, inputs, layers, sm_metrics, outputs
# Epoch 1/5
# [2022-08-13 19:58:18.689 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/prestepzero-*-start-1660420669266300.0_train-0-stepstart-1660420698688786.0/python_stats.
# [2022-08-13 19:58:34.023 ip-10-0-238-49.ec2.internal:34 INFO keras.py:911] Enabling TF profiler on step: = 5
# [2022-08-13 19:58:34.358 ip-10-0-238-49.ec2.internal:34 INFO keras.py:922] Disabling TF profiler on step: =6
# [2022-08-13 19:58:34.549 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-9-stepstart-1660420714503144.8_train-9-stepend-1660420714548567.5/python_stats.
# [2022-08-13 19:58:34.556 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-9-stepend-1660420714552543.5_train-10-stepstart-1660420714555829.0/python_stats.
# [2022-08-13 19:58:34.599 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-10-stepstart-1660420714557785.0_train-10-stepend-1660420714598856.2/python_stats.
# [2022-08-13 19:58:34.608 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-10-stepend-1660420714604484.8_train-11-stepstart-1660420714608004.0/python_stats.
# [2022-08-13 19:58:34.652 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-11-stepstart-1660420714610150.5_train-11-stepend-1660420714651270.8/python_stats.
# [2022-08-13 19:58:34.660 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-11-stepend-1660420714656199.8_train-12-stepstart-1660420714659845.0/python_stats.
# [2022-08-13 19:58:44.598 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-9-stepstart-1660420724554390.8_eval-9-stepend-1660420724597944.5/python_stats.
# [2022-08-13 19:58:44.607 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-9-stepend-1660420724603656.5_eval-10-stepstart-1660420724607553.5/python_stats.
# [2022-08-13 19:58:44.652 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-10-stepstart-1660420724609913.0_eval-10-stepend-1660420724652070.0/python_stats.
# [2022-08-13 19:58:44.664 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-10-stepend-1660420724658387.5_eval-11-stepstart-1660420724663534.2/python_stats.
# [2022-08-13 19:58:44.696 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-11-stepstart-1660420724666896.5_eval-11-stepend-1660420724696164.0/python_stats.
# [2022-08-13 19:58:44.705 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-11-stepend-1660420724701387.0_eval-12-stepstart-1660420724704778.2/python_stats.
# 383/383 - 12s - loss: 0.3637 - accuracy: 0.9971 - val_loss: 0.0064 - val_accuracy: 0.9992 - batch: 0.0000e+00
# Epoch 2/5
# [2022-08-13 19:58:46.231 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-42-stepend-1660420725551839.5_train-383-stepstart-1660420726231197.0/python_stats.
# 383/383 - 12s - loss: 0.0097 - accuracy: 0.9992 - val_loss: 0.0064 - val_accuracy: 0.9992 - batch: 1.0000
# Epoch 3/5
# [2022-08-13 19:59:07.635 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-85-stepend-1660420746906632.2_train-766-stepstart-1660420747634822.8/python_stats.
# 383/383 - 11s - loss: 0.0090 - accuracy: 0.9992 - val_loss: 0.0064 - val_accuracy: 0.9992 - batch: 2.0000
# Epoch 4/5
# [2022-08-13 19:59:28.376 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-128-stepend-1660420767674082.8_train-1149-stepstart-1660420768375811.5/python_stats.
# 383/383 - 11s - loss: 0.0085 - accuracy: 0.9992 - val_loss: 0.0064 - val_accuracy: 0.9992 - batch: 3.0000
# Epoch 5/5
# [2022-08-13 19:59:50.651 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-171-stepend-1660420789969164.8_train-1532-stepstart-1660420790650854.0/python_stats.
# 383/383 - 11s - loss: 0.0084 - accuracy: 0.9992 - val_loss: 0.0065 - val_accuracy: 0.9992 - batch: 4.0000
# [2022-08-13 20:00:10.080 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-214-stepend-1660420810049737.5_train-1914-stepend-1660420810079863.8/python_stats.
# [2022-08-13 20:00:10.421 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-1914-stepend-1660420810087016.0_eval-215-stepstart-1660420810420322.5/python_stats.
# 43/43 - 1s - loss: 0.0065 - accuracy: 0.9992
# [2022-08-13 20:00:26.141 ip-10-0-238-49.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-257-stepend-1660420812647602.8_posthookclose-*-end-1660420826137232.0/python_stats.
# 2022-08-13 19:57:46.636580: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-13 19:57:46.688152: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# INFO:__main__:Executing the main() function...
# INFO:__main__:TensorFlow version : 2.3.1
# INFO:__main__:Parsing command-line arguments...
# INFO:__main__:Completed parsing command-line arguments.
# INFO:__main__:Namespace(batchsize=4096, checkpoint_enabled='False', checkpoint_load_previous='False', checkpoint_local_dir='/opt/ml/checkpoints/', epochs=5, lr=0.004, model_dir='s3://sagemaker-us-east-1-431615879134/ipinyou-csvdl-p32xl-inmem4096-2022-08-13-19-53-19-648/model', seed=42, train_dir='/opt/ml/input/data/train', val_dir='/opt/ml/input/data/validation')
# INFO:__main__:Files in /opt/ml/input/data/train: ['/opt/ml/input/data/train/train.csv']
# INFO:__main__:data loaded from /opt/ml/input/data/train, shapes, input: (1567893, 75), output: (1567893,)
# INFO:__main__:Completed loading and preprocessing data.
# INFO:__main__:Files in /opt/ml/input/data/validation: ['/opt/ml/input/data/validation/test.csv']
# INFO:__main__:data loaded from /opt/ml/input/data/validation, shapes, input: (174211, 75), output: (174211,)
# INFO:__main__:Completed loading and preprocessing data.
# INFO:__main__:Creating the model...
# INFO:__main__:None
# INFO:__main__:Completed creating the model.
# INFO:__main__:Compiling the model...
# INFO:__main__:Completed compiling the model.
# INFO:__main__:Training the model...
# INFO:__main__:Checkpointing will not be performed.
# INFO:__main__:Training duration = 112.84 seconds
# INFO:__main__:Completed training the model.
# INFO:__main__:Evaluating the model...
# INFO:__main__:Test loss = 0.006515810266137123
# INFO:__main__:Test accuracy = 0.9992193579673767
# INFO:__main__:Completed evaluating the model.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2022-08-13 20:00:27,190 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# 2022-08-13 20:00:27,191 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2022-08-13 20:00:15.133618: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: s3://sagemaker-us-east-1-431615879134/ipinyou-csvdl-p32xl-inmem4096-2022-08-13-19-53-19-648/model/000000001/assets
# INFO:tensorflow:Assets written to: s3://sagemaker-us-east-1-431615879134/ipinyou-csvdl-p32xl-inmem4096-2022-08-13-19-53-19-648/model/000000001/assets
# INFO:__main__:Completed executing the main() function.
#
# 2022-08-13 20:00:46 Uploading - Uploading generated training model
# 2022-08-13 20:00:46 Completed - Training job completed
# Training seconds: 333
# Billable seconds: 333
# ipinyou-csvdl-p32xl-inmem4096-2022-08-13-19-53-19-648

# %%
with open('trail_one.txt', 'w') as f:
    for line in namelist:
        f.write(f"{line}\n")

# %% [markdown]
# ## Training with TF Record

# %%
training_config = [
    {
        'job_name':'ipinyou-tf-m52xl-2048',
        'compute':'ml.m5.2xlarge',
        'data_type':'tfrecord',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-tf-c42xl-2048',
        'compute':'ml.c4.2xlarge',
        'data_type':'tfrecord',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-tf-g4dnxl-2048',
        'compute':'ml.g4dn.xlarge',
        'data_type':'tfrecord',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-tf-p32xl-2048',
        'compute':'ml.p3.2xlarge',
        'data_type':'tfrecord',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-tf-m52xl-4096',
        'compute':'ml.m5.2xlarge',
        'data_type':'tfrecord',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-tf-c42xl-4096',
        'compute':'ml.c4.2xlarge',
        'data_type':'tfrecord',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-tf-g4dnxl-4096',
        'compute':'ml.g4dn.xlarge',
        'data_type':'tfrecord',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-tf-p32xl-4096',
        'compute':'ml.p3.2xlarge',
        'data_type':'tfrecord',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':4096,
    }, 
    ##
     {
        'job_name':'ipinyou-tfffm-m52xl-2048',
        'compute':'ml.m5.2xlarge',
        'data_type':'tfrecordffm',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-tfffm-c42xl-2048',
        'compute':'ml.c4.2xlarge',
        'data_type':'tfrecordffm',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-tfffm-g4dnxl-2048',
        'compute':'ml.g4dn.xlarge',
        'data_type':'tfrecordffm',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-tfffm-p32xl-2048',
        'compute':'ml.p3.2xlarge',
        'data_type':'tfrecordffm',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-tfffm-m52xl-4096',
        'compute':'ml.m5.2xlarge',
        'data_type':'tfrecordffm',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-tfffm-c42xl-4096',
        'compute':'ml.c4.2xlarge',
        'data_type':'tfrecordffm',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-tfffm-g4dnxl-4096',
        'compute':'ml.g4dn.xlarge',
        'data_type':'tfrecordffm',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-tfffm-p32xl-4096',
        'compute':'ml.p3.2xlarge',
        'data_type':'tfrecordffm',
        'code':'tf_profile_fit_tfrecord.py',
        'batchsize':4096,
    }, 
    
]

# %%
namelist = []
for train in training_config:
    name = call_training(train)
    namelist.append(name)

# %%
with open('trail_two.txt', 'w') as f:
    for line in namelist:
        f.write(f"{line}\n")

# %% [markdown]
# ## Training with Parquet

# %%
training_config = [
    {
        'job_name':'ipinyou-pq-m52xl-2048',
        'compute':'ml.m5.2xlarge',
        'data_type':'parquet',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-pq-c42xl-2048',
        'compute':'ml.c4.2xlarge',
        'data_type':'parquet',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-pq-g4dnxl-2048',
        'compute':'ml.g4dn.xlarge',
        'data_type':'parquet',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-pq-p32xl-2048',
        'compute':'ml.p3.2xlarge',
        'data_type':'parquet',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-pq-m52xl-4096',
        'compute':'ml.m5.2xlarge',
        'data_type':'parquet',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-pq-c42xl-4096',
        'compute':'ml.c4.2xlarge',
        'data_type':'parquet',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-pq-g4dnxl-4096',
        'compute':'ml.g4dn.xlarge',
        'data_type':'parquet',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-pq-p32xl-4096',
        'compute':'ml.p3.2xlarge',
        'data_type':'parquet',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':4096,
    }, 
    ##
     {
        'job_name':'ipinyou-pqffm-m52xl-2048',
        'compute':'ml.m5.2xlarge',
        'data_type':'parquetffm',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-pqffm-c42xl-2048',
        'compute':'ml.c4.2xlarge',
        'data_type':'parquetffm',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-pqffm-g4dnxl-2048',
        'compute':'ml.g4dn.xlarge',
        'data_type':'parquetffm',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-pqffm-p32xl-2048',
        'compute':'ml.p3.2xlarge',
        'data_type':'parquetffm',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':2048,
    }, 
    
    {
        'job_name':'ipinyou-pqffm-m52xl-4096',
        'compute':'ml.m5.2xlarge',
        'data_type':'parquetffm',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-pqffm-c42xl-4096',
        'compute':'ml.c4.2xlarge',
        'data_type':'parquetffm',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-pqffm-g4dnxl-4096',
        'compute':'ml.g4dn.xlarge',
        'data_type':'parquetffm',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':4096,
    }, 
    
    {
        'job_name':'ipinyou-pqffm-p32xl-4096',
        'compute':'ml.p3.2xlarge',
        'data_type':'parquetffm',
        'code':'tf_profile_fit_parquet.py',
        'batchsize':4096,
    }, 
    
]

# %%
namelist = []
for train in training_config:
    name = call_training(train)
    namelist.append(name)
# Out:
# {'job_name': 'ipinyou-pq-m52xl-2048', 'compute': 'ml.m5.2xlarge', 'data_type': 'parquet', 'code': 'tf_profile_fit_parquet.py', 'batchsize': 2048}
# 2022-08-15 13:44:58 Starting - Starting the training job...
# 2022-08-15 13:45:22 Starting - Preparing the instances for trainingLossNotDecreasing: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# StalledTrainingRule: InProgress
# ProfilerReport: InProgress
# ............
# 2022-08-15 13:47:30 Downloading - Downloading input data
# 2022-08-15 13:47:30 Training - Downloading the training image...
# 2022-08-15 13:48:00 Training - Training image download completed. Training in progress..2022-08-15 13:47:55.022269: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-15 13:47:55.026051: I tensorflow/core/profiler/internal/smprofiler_config_reader.cc:123] PID of the process that is writing to the timeline : 1
# 2022-08-15 13:47:55.026732: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:121] SageMaker Profiler Timeline Writer read the following config parameters :
# 2022-08-15 13:47:55.026758: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:122] Base Folder : /opt/ml/output/profiler
# 2022-08-15 13:47:55.026765: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:123] Node Id : 1-algo-1
# 2022-08-15 13:47:55.026773: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:124] Maximum file size : 10485760
# 2022-08-15 13:47:55.026783: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:125] Close file interval : 60
# 2022-08-15 13:47:55.026790: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:126] Continuous fail count threshold : 50
# 2022-08-15 13:47:55.026804: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:144] PID of the current Timeline Process : 1
# 2022-08-15 13:47:55.182627: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-15 13:47:57,858 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-08-15 13:47:57,865 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-15 13:47:58,311 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-15 13:47:58,333 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-15 13:47:58,355 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-15 13:47:58,368 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batchsize": 2048,
#         "epochs": 5,
#         "lr": 0.004,
#         "model_dir": "s3://sagemaker-us-east-1-431615879134/ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-431615879134/ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361/source/sourcedir.tar.gz",
#     "module_name": "tf_profile_fit_parquet",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "tf_profile_fit_parquet.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batchsize":2048,"epochs":5,"lr":0.004,"model_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361/model"}
# SM_USER_ENTRY_POINT=tf_profile_fit_parquet.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=tf_profile_fit_parquet
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batchsize":2048,"epochs":5,"lr":0.004,"model_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361/source/sourcedir.tar.gz","module_name":"tf_profile_fit_parquet","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"tf_profile_fit_parquet.py"}
# SM_USER_ARGS=["--batchsize","2048","--epochs","5","--lr","0.004","--model_dir","s3://sagemaker-us-east-1-431615879134/ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_BATCHSIZE=2048
# SM_HP_EPOCHS=5
# SM_HP_LR=0.004
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 tf_profile_fit_parquet.py --batchsize 2048 --epochs 5 --lr 0.004 --model_dir s3://sagemaker-us-east-1-431615879134/ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361/model
# [2022-08-15 13:48:00.423 ip-10-2-75-17.ec2.internal:34 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-08-15 13:48:00.665 ip-10-2-75-17.ec2.internal:34 INFO profiler_config_parser.py:102] Using config at /opt/ml/input/config/profilerconfig.json.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               9728
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 42,881
# Trainable params: 42,881
# Non-trainable params: 0
# _________________________________________________________________
# [2022-08-15 13:48:03.290 ip-10-2-75-17.ec2.internal:34 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-08-15 13:48:03.293 ip-10-2-75-17.ec2.internal:34 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-08-15 13:48:03.295 ip-10-2-75-17.ec2.internal:34 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2022-08-15 13:48:03.296 ip-10-2-75-17.ec2.internal:34 INFO state_store.py:75] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-08-15 13:48:03.328 ip-10-2-75-17.ec2.internal:34 INFO hook.py:413] Monitoring the collections: outputs, metrics, layers, gradients, inputs, losses, sm_metrics
# Epoch 1/5
# [2022-08-15 13:48:04.255 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/prestepzero-*-start-1660571280666287.0_train-0-stepstart-1660571284255310.0/python_stats.
# [2022-08-15 13:48:11.551 ip-10-2-75-17.ec2.internal:34 INFO keras.py:911] Enabling TF profiler on step: = 5
# [2022-08-15 13:48:11.580 ip-10-2-75-17.ec2.internal:34 INFO keras.py:922] Disabling TF profiler on step: =6
# [2022-08-15 13:48:11.780 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-9-stepstart-1660571291725437.0_train-9-stepend-1660571291780130.5/python_stats.
# [2022-08-15 13:48:11.786 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-9-stepend-1660571291783875.0_train-10-stepstart-1660571291786251.0/python_stats.
# [2022-08-15 13:48:11.846 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-10-stepstart-1660571291787955.2_train-10-stepend-1660571291845809.2/python_stats.
# [2022-08-15 13:48:11.850 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-10-stepend-1660571291848101.5_train-11-stepstart-1660571291850131.0/python_stats.
# [2022-08-15 13:48:11.901 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-11-stepstart-1660571291851134.0_train-11-stepend-1660571291900956.5/python_stats.
# [2022-08-15 13:48:11.905 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-11-stepend-1660571291903221.0_train-12-stepstart-1660571291904964.8/python_stats.
# [2022-08-15 13:48:37.417 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-9-stepstart-1660571317391539.5_eval-9-stepend-1660571317417325.8/python_stats.
# [2022-08-15 13:48:37.421 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-9-stepend-1660571317419551.8_eval-10-stepstart-1660571317421189.8/python_stats.
# [2022-08-15 13:48:37.447 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-10-stepstart-1660571317422289.0_eval-10-stepend-1660571317447419.2/python_stats.
# [2022-08-15 13:48:37.451 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-10-stepend-1660571317449472.0_eval-11-stepstart-1660571317451072.5/python_stats.
# [2022-08-15 13:48:37.478 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-11-stepstart-1660571317452169.8_eval-11-stepend-1660571317478281.5/python_stats.
# [2022-08-15 13:48:37.483 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-11-stepend-1660571317481041.8_eval-12-stepstart-1660571317483078.5/python_stats.
# 766/766 - 27s - loss: 0.1890 - accuracy: 0.9981 - val_loss: 0.0065 - val_accuracy: 0.9992 - batch: 0.0000e+00
# Epoch 2/5
# [2022-08-15 13:48:38.699 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-85-stepend-1660571318195218.0_train-766-stepstart-1660571318699356.2/python_stats.
# 766/766 - 28s - loss: 0.0089 - accuracy: 0.9992 - val_loss: 0.0064 - val_accuracy: 0.9992 - batch: 1.0000
# Epoch 3/5
# [2022-08-15 13:49:10.094 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-171-stepend-1660571349702666.8_train-1532-stepstart-1660571350093774.2/python_stats.
# 766/766 - 26s - loss: 0.0085 - accuracy: 0.9992 - val_loss: 0.0064 - val_accuracy: 0.9992 - batch: 2.0000
# Epoch 4/5
# [2022-08-15 13:49:39.865 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-257-stepend-1660571379553397.5_train-2298-stepstart-1660571379864750.2/python_stats.
# 766/766 - 27s - loss: 0.0082 - accuracy: 0.9992 - val_loss: 0.0063 - val_accuracy: 0.9992 - batch: 3.0000
# Epoch 5/5
# [2022-08-15 13:50:10.667 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-343-stepend-1660571410404389.2_train-3064-stepstart-1660571410666858.2/python_stats.
# 766/766 - 26s - loss: 0.0079 - accuracy: 0.9992 - val_loss: 0.0069 - val_accuracy: 0.9992 - batch: 4.0000
# [2022-08-15 13:50:40.198 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-429-stepend-1660571440175943.2_train-3829-stepend-1660571440198418.2/python_stats.
# [2022-08-15 13:50:40.327 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-3829-stepend-1660571440202453.0_eval-430-stepstart-1660571440326789.5/python_stats.
# 86/86 - 1s - loss: 0.0069 - accuracy: 0.9992
#
# 2022-08-15 13:51:04 Uploading - Uploading generated training model
# 2022-08-15 13:51:04 Completed - Training job completed
# [2022-08-15 13:50:51.929 ip-10-2-75-17.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-515-stepend-1660571441478331.5_posthookclose-*-end-1660571451923882.2/python_stats.
# 2022-08-15 13:47:58.887836: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-15 13:47:58.918142: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# INFO:__main__:Executing the main() function...
# INFO:__main__:TensorFlow version : 2.3.1
# INFO:__main__:Parsing command-line arguments...
# INFO:__main__:Completed parsing command-line arguments.
# INFO:__main__:Namespace(batchsize=2048, checkpoint_enabled='False', checkpoint_load_previous='False', checkpoint_local_dir='/opt/ml/checkpoints/', epochs=5, lr=0.004, model_dir='s3://sagemaker-us-east-1-431615879134/ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361/model', seed=42, train_dir='/opt/ml/input/data/train', val_dir='/opt/ml/input/data/validation')
# INFO:__main__:Files in /opt/ml/input/data/train: []
# INFO:__main__:data loaded from /opt/ml/input/data/train, shapes, input: (1567893, 75), output: (1567893,)
# INFO:__main__:Completed loading and preprocessing data.
# INFO:__main__:Files in /opt/ml/input/data/validation: []
# INFO:__main__:data loaded from /opt/ml/input/data/validation, shapes, input: (174211, 75), output: (174211,)
# INFO:__main__:Completed loading and preprocessing data.
# INFO:__main__:Creating the model...
# INFO:__main__:None
# INFO:__main__:Completed creating the model.
# INFO:__main__:Compiling the model...
# INFO:__main__:Completed compiling the model.
# INFO:__main__:Training the model...
# INFO:__main__:Checkpointing will not be performed.
# INFO:__main__:Training duration = 156.93 seconds
# INFO:__main__:Completed training the model.
# INFO:__main__:Evaluating the model...
# INFO:__main__:Test loss = 0.006863503251224756
# INFO:__main__:Test accuracy = 0.9992193579673767
# INFO:__main__:Completed evaluating the model.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2022-08-15 13:50:43.238873: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: s3://sagemaker-us-east-1-431615879134/ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361/model/000000001/assets
# INFO:tensorflow:Assets written to: s3://sagemaker-us-east-1-431615879134/ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361/model/000000001/assets
# 2022-08-15 13:50:52,439 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# INFO:__main__:Completed executing the main() function.
# 2022-08-15 13:50:52,439 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 238
# Billable seconds: 238
# ipinyou-pq-m52xl-2048-2022-08-15-13-44-58-361
# {'job_name': 'ipinyou-pq-c42xl-2048', 'compute': 'ml.c4.2xlarge', 'data_type': 'parquet', 'code': 'tf_profile_fit_parquet.py', 'batchsize': 2048}
# 2022-08-15 13:51:15 Starting - Starting the training job...
# 2022-08-15 13:51:39 Starting - Preparing the instances for trainingLossNotDecreasing: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# StalledTrainingRule: InProgress
# ProfilerReport: InProgress
# .........
# 2022-08-15 13:53:07 Downloading - Downloading input data...
# 2022-08-15 13:53:39 Training - Downloading the training image..2022-08-15 13:53:51.638716: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-15 13:53:51.650221: I tensorflow/core/profiler/internal/smprofiler_config_reader.cc:123] PID of the process that is writing to the timeline : 1
# 2022-08-15 13:53:51.652325: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:121] SageMaker Profiler Timeline Writer read the following config parameters :
# 2022-08-15 13:53:51.652343: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:122] Base Folder : /opt/ml/output/profiler
# 2022-08-15 13:53:51.652349: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:123] Node Id : 1-algo-1
# 2022-08-15 13:53:51.652384: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:124] Maximum file size : 10485760
# 2022-08-15 13:53:51.652398: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:125] Close file interval : 60
# 2022-08-15 13:53:51.652420: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:126] Continuous fail count threshold : 50
# 2022-08-15 13:53:51.652433: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:144] PID of the current Timeline Process : 1
# 2022-08-15 13:53:52.030081: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-15 13:53:56,585 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-08-15 13:53:56,593 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-15 13:53:57,322 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-15 13:53:57,341 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-15 13:53:57,357 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-08-15 13:53:57,369 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batchsize": 2048,
#         "epochs": 5,
#         "lr": 0.004,
#         "model_dir": "s3://sagemaker-us-east-1-431615879134/ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-431615879134/ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117/source/sourcedir.tar.gz",
#     "module_name": "tf_profile_fit_parquet",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.c4.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.c4.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "tf_profile_fit_parquet.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batchsize":2048,"epochs":5,"lr":0.004,"model_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117/model"}
# SM_USER_ENTRY_POINT=tf_profile_fit_parquet.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c4.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c4.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=tf_profile_fit_parquet
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batchsize":2048,"epochs":5,"lr":0.004,"model_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117/source/sourcedir.tar.gz","module_name":"tf_profile_fit_parquet","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c4.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c4.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"tf_profile_fit_parquet.py"}
# SM_USER_ARGS=["--batchsize","2048","--epochs","5","--lr","0.004","--model_dir","s3://sagemaker-us-east-1-431615879134/ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_BATCHSIZE=2048
# SM_HP_EPOCHS=5
# SM_HP_LR=0.004
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 tf_profile_fit_parquet.py --batchsize 2048 --epochs 5 --lr 0.004 --model_dir s3://sagemaker-us-east-1-431615879134/ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117/model
# [2022-08-15 13:53:59.598 ip-10-2-226-18.ec2.internal:35 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-08-15 13:53:59.997 ip-10-2-226-18.ec2.internal:35 INFO profiler_config_parser.py:102] Using config at /opt/ml/input/config/profilerconfig.json.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               9728
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 42,881
# Trainable params: 42,881
# Non-trainable params: 0
# _________________________________________________________________
# [2022-08-15 13:54:02.999 ip-10-2-226-18.ec2.internal:35 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-08-15 13:54:03.002 ip-10-2-226-18.ec2.internal:35 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-08-15 13:54:03.005 ip-10-2-226-18.ec2.internal:35 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2022-08-15 13:54:03.005 ip-10-2-226-18.ec2.internal:35 INFO state_store.py:75] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-08-15 13:54:03.046 ip-10-2-226-18.ec2.internal:35 INFO hook.py:413] Monitoring the collections: metrics, sm_metrics, inputs, outputs, layers, losses, gradients
#
# 2022-08-15 13:54:07 Training - Training image download completed. Training in progress.Epoch 1/5
# [2022-08-15 13:54:04.043 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/prestepzero-*-start-1660571639997412.2_train-0-stepstart-1660571644042794.5/python_stats.
# [2022-08-15 13:54:16.149 ip-10-2-226-18.ec2.internal:35 INFO keras.py:911] Enabling TF profiler on step: = 5
# [2022-08-15 13:54:16.202 ip-10-2-226-18.ec2.internal:35 INFO keras.py:922] Disabling TF profiler on step: =6
# [2022-08-15 13:54:16.518 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/train-9-stepstart-1660571656427126.0_train-9-stepend-1660571656518332.8/python_stats.
# [2022-08-15 13:54:16.524 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/train-9-stepend-1660571656522003.0_train-10-stepstart-1660571656524144.0/python_stats.
# [2022-08-15 13:54:16.595 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/train-10-stepstart-1660571656525517.5_train-10-stepend-1660571656594895.0/python_stats.
# [2022-08-15 13:54:16.601 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/train-10-stepend-1660571656598283.0_train-11-stepstart-1660571656600956.8/python_stats.
# [2022-08-15 13:54:16.681 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/train-11-stepstart-1660571656602563.5_train-11-stepend-1660571656680607.2/python_stats.
# [2022-08-15 13:54:16.688 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/train-11-stepend-1660571656685034.2_train-12-stepstart-1660571656687923.2/python_stats.
# [2022-08-15 13:54:48.811 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/eval-9-stepstart-1660571688768876.8_eval-9-stepend-1660571688810237.0/python_stats.
# [2022-08-15 13:54:48.818 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/eval-9-stepend-1660571688814747.5_eval-10-stepstart-1660571688817664.5/python_stats.
# [2022-08-15 13:54:48.865 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/eval-10-stepstart-1660571688819952.0_eval-10-stepend-1660571688865227.0/python_stats.
# [2022-08-15 13:54:48.871 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/eval-10-stepend-1660571688868311.0_eval-11-stepstart-1660571688870938.5/python_stats.
# [2022-08-15 13:54:48.915 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/eval-11-stepstart-1660571688872525.0_eval-11-stepend-1660571688915461.0/python_stats.
# [2022-08-15 13:54:48.920 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/eval-11-stepend-1660571688918361.8_eval-12-stepstart-1660571688920464.8/python_stats.
# 766/766 - 34s - loss: 0.1892 - accuracy: 0.9981 - val_loss: 0.0068 - val_accuracy: 0.9992 - batch: 0.0000e+00
# Epoch 2/5
# [2022-08-15 13:54:50.895 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/eval-85-stepend-1660571690349565.8_train-766-stepstart-1660571690895310.5/python_stats.
# 766/766 - 34s - loss: 0.0090 - accuracy: 0.9992 - val_loss: 0.0064 - val_accuracy: 0.9992 - batch: 1.0000
# Epoch 3/5
# [2022-08-15 13:55:32.150 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/eval-171-stepend-1660571731788041.0_train-1532-stepstart-1660571732149635.0/python_stats.
# 766/766 - 33s - loss: 0.0087 - accuracy: 0.9992 - val_loss: 0.0063 - val_accuracy: 0.9992 - batch: 2.0000
# Epoch 4/5
# [2022-08-15 13:56:12.455 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/eval-257-stepend-1660571772098163.2_train-2298-stepstart-1660571772454801.2/python_stats.
# 766/766 - 31s - loss: 0.0082 - accuracy: 0.9992 - val_loss: 0.0063 - val_accuracy: 0.9992 - batch: 3.0000
# Epoch 5/5
# [2022-08-15 13:56:50.957 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/eval-343-stepend-1660571810579054.8_train-3064-stepstart-1660571810956974.0/python_stats.
# 766/766 - 33s - loss: 0.0081 - accuracy: 0.9992 - val_loss: 0.0069 - val_accuracy: 0.9992 - batch: 4.0000
# [2022-08-15 13:57:30.976 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/eval-429-stepend-1660571850947240.5_train-3829-stepend-1660571850975712.2/python_stats.
# [2022-08-15 13:57:31.159 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/train-3829-stepend-1660571850981278.2_eval-430-stepstart-1660571851158573.8/python_stats.
# 86/86 - 1s - loss: 0.0069 - accuracy: 0.9992
#
# 2022-08-15 13:57:49 Uploading - Uploading generated training model[2022-08-15 13:57:45.585 ip-10-2-226-18.ec2.internal:35 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/35-algo-1/eval-515-stepend-1660571853297073.0_posthookclose-*-end-1660571865583395.2/python_stats.
# 2022-08-15 13:53:57.905851: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-15 13:53:57.935060: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# INFO:__main__:Executing the main() function...
# INFO:__main__:TensorFlow version : 2.3.1
# INFO:__main__:Parsing command-line arguments...
# INFO:__main__:Completed parsing command-line arguments.
# INFO:__main__:Namespace(batchsize=2048, checkpoint_enabled='False', checkpoint_load_previous='False', checkpoint_local_dir='/opt/ml/checkpoints/', epochs=5, lr=0.004, model_dir='s3://sagemaker-us-east-1-431615879134/ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117/model', seed=42, train_dir='/opt/ml/input/data/train', val_dir='/opt/ml/input/data/validation')
# INFO:__main__:Files in /opt/ml/input/data/train: []
# INFO:__main__:data loaded from /opt/ml/input/data/train, shapes, input: (1567893, 75), output: (1567893,)
# INFO:__main__:Completed loading and preprocessing data.
# INFO:__main__:Files in /opt/ml/input/data/validation: []
# INFO:__main__:data loaded from /opt/ml/input/data/validation, shapes, input: (174211, 75), output: (174211,)
# INFO:__main__:Completed loading and preprocessing data.
# INFO:__main__:Creating the model...
# INFO:__main__:None
# INFO:__main__:Completed creating the model.
# INFO:__main__:Compiling the model...
# INFO:__main__:Completed compiling the model.
# INFO:__main__:Training the model...
# INFO:__main__:Checkpointing will not be performed.
# INFO:__main__:Training duration = 208.00 seconds
# INFO:__main__:Completed training the model.
# INFO:__main__:Evaluating the model...
# INFO:__main__:Test loss = 0.006896739825606346
# INFO:__main__:Test accuracy = 0.9992193579673767
# INFO:__main__:Completed evaluating the model.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2022-08-15 13:57:35.404478: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2022-08-15 13:57:46,294 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2022-08-15 13:57:46,295 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# INFO:tensorflow:Assets written to: s3://sagemaker-us-east-1-431615879134/ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117/model/000000001/assets
# INFO:tensorflow:Assets written to: s3://sagemaker-us-east-1-431615879134/ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117/model/000000001/assets
# INFO:__main__:Completed executing the main() function.
#
# 2022-08-15 13:58:21 Completed - Training job completed
# ProfilerReport: NoIssuesFound
# Training seconds: 303
# Billable seconds: 303
# ipinyou-pq-c42xl-2048-2022-08-15-13-51-15-117
# {'job_name': 'ipinyou-pq-g4dnxl-2048', 'compute': 'ml.g4dn.xlarge', 'data_type': 'parquet', 'code': 'tf_profile_fit_parquet.py', 'batchsize': 2048}
# 2022-08-15 13:58:37 Starting - Starting the training job...
# 2022-08-15 13:59:00 Starting - Preparing the instances for trainingLossNotDecreasing: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# StalledTrainingRule: InProgress
# ProfilerReport: InProgress
# .........
# 2022-08-15 14:00:38 Downloading - Downloading input data
# 2022-08-15 14:00:38 Training - Downloading the training image...............
# 2022-08-15 14:03:01 Training - Training image download completed. Training in progress..2022-08-15 14:03:01.678265: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-15 14:03:01.685440: I tensorflow/core/profiler/internal/smprofiler_config_reader.cc:123] PID of the process that is writing to the timeline : 1
# 2022-08-15 14:03:01.685906: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:121] SageMaker Profiler Timeline Writer read the following config parameters :
# 2022-08-15 14:03:01.685931: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:122] Base Folder : /opt/ml/output/profiler
# 2022-08-15 14:03:01.685939: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:123] Node Id : 1-algo-1
# 2022-08-15 14:03:01.685948: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:124] Maximum file size : 10485760
# 2022-08-15 14:03:01.685954: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:125] Close file interval : 60
# 2022-08-15 14:03:01.685961: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:126] Continuous fail count threshold : 50
# 2022-08-15 14:03:01.685971: I tensorflow/core/profiler/internal/smprofiler_timeline.cc:144] PID of the current Timeline Process : 1
# 2022-08-15 14:03:02.145048: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2022-08-15 14:03:02.394837: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-15 14:03:12,512 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-08-15 14:03:13,850 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batchsize": 2048,
#         "epochs": 5,
#         "lr": 0.004,
#         "model_dir": "s3://sagemaker-us-east-1-431615879134/ipinyou-pq-g4dnxl-2048-2022-08-15-13-58-36-842/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "ipinyou-pq-g4dnxl-2048-2022-08-15-13-58-36-842",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-431615879134/ipinyou-pq-g4dnxl-2048-2022-08-15-13-58-36-842/source/sourcedir.tar.gz",
#     "module_name": "tf_profile_fit_parquet",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g4dn.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g4dn.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "tf_profile_fit_parquet.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batchsize":2048,"epochs":5,"lr":0.004,"model_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-pq-g4dnxl-2048-2022-08-15-13-58-36-842/model"}
# SM_USER_ENTRY_POINT=tf_profile_fit_parquet.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=tf_profile_fit_parquet
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-pq-g4dnxl-2048-2022-08-15-13-58-36-842/source/sourcedir.tar.gz
# ...
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=tf_profile_fit_parquet
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-pqffm-p32xl-4096-2022-08-15-15-26-06-847/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batchsize":4096,"epochs":5,"lr":0.004,"model_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-pqffm-p32xl-4096-2022-08-15-15-26-06-847/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"ipinyou-pqffm-p32xl-4096-2022-08-15-15-26-06-847","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-431615879134/ipinyou-pqffm-p32xl-4096-2022-08-15-15-26-06-847/source/sourcedir.tar.gz","module_name":"tf_profile_fit_parquet","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"tf_profile_fit_parquet.py"}
# SM_USER_ARGS=["--batchsize","4096","--epochs","5","--lr","0.004","--model_dir","s3://sagemaker-us-east-1-431615879134/ipinyou-pqffm-p32xl-4096-2022-08-15-15-26-06-847/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_BATCHSIZE=4096
# SM_HP_EPOCHS=5
# SM_HP_LR=0.004
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-431615879134/ipinyou-pqffm-p32xl-4096-2022-08-15-15-26-06-847/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 tf_profile_fit_parquet.py --batchsize 4096 --epochs 5 --lr 0.004 --model_dir s3://sagemaker-us-east-1-431615879134/ipinyou-pqffm-p32xl-4096-2022-08-15-15-26-06-847/model
# [2022-08-15 15:30:45.531 ip-10-2-230-104.ec2.internal:34 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-08-15 15:30:46.123 ip-10-2-230-104.ec2.internal:34 INFO profiler_config_parser.py:102] Using config at /opt/ml/input/config/profilerconfig.json.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               9728
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 42,881
# Trainable params: 42,881
# Non-trainable params: 0
# _________________________________________________________________
# [2022-08-15 15:30:59.839 ip-10-2-230-104.ec2.internal:34 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-08-15 15:30:59.844 ip-10-2-230-104.ec2.internal:34 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-08-15 15:30:59.847 ip-10-2-230-104.ec2.internal:34 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2022-08-15 15:30:59.848 ip-10-2-230-104.ec2.internal:34 INFO state_store.py:75] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-08-15 15:30:59.901 ip-10-2-230-104.ec2.internal:34 INFO hook.py:413] Monitoring the collections: outputs, layers, gradients, inputs, losses, sm_metrics, metrics
# Epoch 1/5
# [2022-08-15 15:31:01.111 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/prestepzero-*-start-1660577446124641.0_train-0-stepstart-1660577461111027.0/python_stats.
# [2022-08-15 15:31:16.054 ip-10-2-230-104.ec2.internal:34 INFO keras.py:911] Enabling TF profiler on step: = 5
# [2022-08-15 15:31:16.509 ip-10-2-230-104.ec2.internal:34 INFO keras.py:922] Disabling TF profiler on step: =6
# [2022-08-15 15:31:16.745 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-9-stepstart-1660577476697939.5_train-9-stepend-1660577476744982.2/python_stats.
# [2022-08-15 15:31:16.758 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-9-stepend-1660577476749891.2_train-10-stepstart-1660577476757844.2/python_stats.
# [2022-08-15 15:31:16.810 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-10-stepstart-1660577476761042.0_train-10-stepend-1660577476810291.8/python_stats.
# [2022-08-15 15:31:16.818 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-10-stepend-1660577476814655.5_train-11-stepstart-1660577476818399.8/python_stats.
# [2022-08-15 15:31:16.868 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-11-stepstart-1660577476820666.0_train-11-stepend-1660577476867974.0/python_stats.
# [2022-08-15 15:31:16.876 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-11-stepend-1660577476872443.2_train-12-stepstart-1660577476876194.5/python_stats.
# [2022-08-15 15:31:25.324 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-9-stepstart-1660577485286272.8_eval-9-stepend-1660577485323910.8/python_stats.
# [2022-08-15 15:31:25.331 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-9-stepend-1660577485328057.8_eval-10-stepstart-1660577485331415.8/python_stats.
# [2022-08-15 15:31:25.373 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-10-stepstart-1660577485333318.2_eval-10-stepend-1660577485372616.2/python_stats.
# [2022-08-15 15:31:25.381 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-10-stepend-1660577485377056.2_eval-11-stepstart-1660577485380937.8/python_stats.
# [2022-08-15 15:31:25.434 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-11-stepstart-1660577485383439.0_eval-11-stepend-1660577485434285.5/python_stats.
# [2022-08-15 15:31:25.443 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-11-stepend-1660577485438932.0_eval-12-stepstart-1660577485442706.5/python_stats.
# 383/383 - 10s - loss: 0.3562 - accuracy: 0.9971 - val_loss: 0.0065 - val_accuracy: 0.9992 - batch: 0.0000e+00
# Epoch 2/5
# [2022-08-15 15:31:26.542 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-42-stepend-1660577485913318.2_train-383-stepstart-1660577486542083.5/python_stats.
# 383/383 - 9s - loss: 0.0095 - accuracy: 0.9992 - val_loss: 0.0067 - val_accuracy: 0.9992 - batch: 1.0000
# Epoch 3/5
# [2022-08-15 15:31:44.077 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-85-stepend-1660577503445457.2_train-766-stepstart-1660577504077586.0/python_stats.
# 383/383 - 9s - loss: 0.0088 - accuracy: 0.9992 - val_loss: 0.0065 - val_accuracy: 0.9992 - batch: 2.0000
# Epoch 4/5
# [2022-08-15 15:32:01.304 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-128-stepend-1660577520659374.2_train-1149-stepstart-1660577521303979.8/python_stats.
# 383/383 - 9s - loss: 0.0088 - accuracy: 0.9992 - val_loss: 0.0068 - val_accuracy: 0.9992 - batch: 3.0000
# Epoch 5/5
# [2022-08-15 15:32:19.084 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-171-stepend-1660577538494498.5_train-1532-stepstart-1660577539084447.0/python_stats.
# 383/383 - 9s - loss: 0.0084 - accuracy: 0.9992 - val_loss: 0.0064 - val_accuracy: 0.9992 - batch: 4.0000
# [2022-08-15 15:32:35.825 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-214-stepend-1660577555792089.0_train-1914-stepend-1660577555825131.0/python_stats.
# [2022-08-15 15:32:36.024 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/train-1914-stepend-1660577555829867.8_eval-215-stepstart-1660577556024618.5/python_stats.
# 43/43 - 1s - loss: 0.0064 - accuracy: 0.9992
# [2022-08-15 15:32:52.424 ip-10-2-230-104.ec2.internal:34 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/tensorflow/cprofile/34-algo-1/eval-257-stepend-1660577557694474.0_posthookclose-*-end-1660577572421402.2/python_stats.
# 2022-08-15 15:30:43.546048: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-08-15 15:30:43.597751: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# INFO:__main__:Executing the main() function...
# INFO:__main__:TensorFlow version : 2.3.1
# INFO:__main__:Parsing command-line arguments...
# INFO:__main__:Completed parsing command-line arguments.
# INFO:__main__:Namespace(batchsize=4096, checkpoint_enabled='False', checkpoint_load_previous='False', checkpoint_local_dir='/opt/ml/checkpoints/', epochs=5, lr=0.004, model_dir='s3://sagemaker-us-east-1-431615879134/ipinyou-pqffm-p32xl-4096-2022-08-15-15-26-06-847/model', seed=42, train_dir='/opt/ml/input/data/train', val_dir='/opt/ml/input/data/validation')
# INFO:__main__:Files in /opt/ml/input/data/train: []
# INFO:__main__:data loaded from /opt/ml/input/data/train, shapes, input: (1567893, 75), output: (1567893,)
# INFO:__main__:Completed loading and preprocessing data.
# INFO:__main__:Files in /opt/ml/input/data/validation: []
# INFO:__main__:data loaded from /opt/ml/input/data/validation, shapes, input: (174211, 75), output: (174211,)
# INFO:__main__:Completed loading and preprocessing data.
# INFO:__main__:Creating the model...
# INFO:__main__:None
# INFO:__main__:Completed creating the model.
# INFO:__main__:Compiling the model...
# INFO:__main__:Completed compiling the model.
# INFO:__main__:Training the model...
# INFO:__main__:Checkpointing will not be performed.
# WARNING:tensorflow:Callbacks method `on_test_batch_begin` is slow compared to the batch time (batch time: 0.0031s vs `on_test_batch_begin` time: 0.0051s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_test_batch_begin` is slow compared to the batch time (batch time: 0.0031s vs `on_test_batch_begin` time: 0.0051s). Check your callbacks.
# INFO:__main__:Training duration = 96.02 seconds
# INFO:__main__:Completed training the model.
# INFO:__main__:Evaluating the model...
# INFO:__main__:Test loss = 0.006357693113386631
# INFO:__main__:Test accuracy = 0.9992193579673767
# INFO:__main__:Completed evaluating the model.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2022-08-15 15:32:40.187807: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: s3://sagemaker-us-east-1-431615879134/ipinyou-pqffm-p32xl-4096-2022-08-15-15-26-06-847/model/000000001/assets
# INFO:tensorflow:Assets written to: s3://sagemaker-us-east-1-431615879134/ipinyou-pqffm-p32xl-4096-2022-08-15-15-26-06-847/model/000000001/assets
# INFO:__main__:Completed executing the main() function.
# 2022-08-15 15:32:53,568 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2022-08-15 15:32:53,569 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2022-08-15 15:33:12 Uploading - Uploading generated training model
# 2022-08-15 15:33:12 Completed - Training job completed
# ProfilerReport: IssuesFound
# Training seconds: 313
# Billable seconds: 313
# ipinyou-pqffm-p32xl-4096-2022-08-15-15-26-06-847

# %%
with open('trail_three.txt', 'w') as f:
    for line in namelist:
        f.write(f"{line}\n")
