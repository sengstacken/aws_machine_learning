# %% [markdown]
# # Interacting with Recommenders and Campaigns <a class="anchor" id="top"></a>
#
# In this notebook, you will deploy and interact with campaigns in Amazon Personalize.
#
# 1. [Introduction](#intro)
# 1. [Interact with Recommenders](#interact-recommenders)
# 1. [Interact with Campaigns](#interact-campaigns)
# 1. [Using Static and Dynamic Filters](#filters)
# 1. [Real-time Events](#real-time)
# 1. [Batch Recommendations](#batch)
# 1. [Wrap Up](#wrapup)
#
# ## Introduction <a class="anchor" id="intro"></a>
# [Back to top](#top)
#
# At this point, you should have 2 Recommenders and one deployed campaign. Once they are active, there are resources for querying the recommendations, and helper functions to digest the output into something more human-readable.
#
#
# In this Notebook we will interact with Recommenders and Campaigns and get recommendatiosn. We will interact with filters and send live data to Amazon Personalize to see the effect on recommendations.
#
# ![Workflow](images/image3.png)
#
# To run this notebook, you need to have run the previous notebooks, `01_Data_Layer.ipynb`, and `02_Training_Layer.ipynb`, where you created a dataset and imported interaction, item, and user metadata data into Amazon Personalize, created recommenders, solutions and campaigns. At the end of that notebook, you saved some of the variable values, which you now need to load into this notebook.
#
# As you work with your customer on Amazon Personalize, you can modify the helper functions to fit the structure of their data input files to keep the additional rendering working.
#
# To get started, once again, we need to import libraries, load values from previous notebooks, and load the SDK.

# %%
import time
from time import sleep
import json
from datetime import datetime
import uuid
import random
import boto3
import pandas as pd

# %%
# %store -r

# %%
personalize = boto3.client('personalize')
personalize_runtime = boto3.client('personalize-runtime')

# Establish a connection to Personalize's event streaming
personalize_events = boto3.client(service_name='personalize-events')

# %% [markdown]
# First, let's create a supporting function to help make sense of the results returned by a Personalize recommender or campaign. Personalize returns only an `item_id`. This is great for keeping data compact, but it means you need to query a database or lookup table to get a human-readable result for the notebooks. We will create a helper function to return a human-readable result from the Movielens dataset.
#
# Start by loading in the dataset which we can use for our lookup table.

# %%
# Create a dataframe for the items by reading in the correct source CSV
items_df = pd.read_csv(dataset_dir + '/movies.csv', sep=',', usecols=[0,1], encoding='latin-1', dtype={'movieId': "object", 'title': "str"},index_col=0)

# Render some sample data
items_df.head(5)
# Out:
#                                       title
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)

# %% [markdown]
# By defining the ID column as the index column it is trivial to return a movie by just querying the ID. Movie #589 should be Terminator 2: Judgment Day.

# %%
movieIdExample = 589
title = items_df.loc[movieIdExample]['title']
print(title)
# Out:
# Terminator 2: Judgment Day (1991)

# %% [markdown]
# That isn't terrible, but it would get messy to repeat this everywhere in our code, so the function below will clean that up.

# %%
def get_movie_by_id(movieId, movie_df=items_df):
    """
    This takes in an artist_id from Personalize so it will be a string,
    converts it to an int, and then does a lookup in a default or specified
    dataframe.
    
    A really broad try/except clause was added in case anything goes wrong.
    
    Feel free to add more debugging or filtering here to improve results if
    you hit an error.
    """
    try:
        return movie_df.loc[int(movieId)]['title']
    except:
        return "Error obtaining title"

# %% [markdown]
# Now let's test a few simple values to check our error catching.

# %%
# A known good id (The Princess Bride)
print(get_movie_by_id(movieId="1197"))
# A bad type of value
print(get_movie_by_id(movieId="987.9393939"))
# Really bad values
print(get_movie_by_id(movieId="Steve"))
# Out:
# Princess Bride, The (1987)
# Error obtaining title
# Error obtaining title

# %% [markdown]
# Great! Now we have a way of rendering results.

# %% [markdown]
# ## Interact with recommenders <a class="anchor" id="interact-recommenders"></a>
# [Back to top](#top)
#
# Now that the recommenders have been trained, lets have a look at the recommendations we can get for our users!

# %% [markdown]
# ### "More like X" Recommender
#
# 'More like X' requires an item and a user as input, and it will return items which users interact with in similar ways to their interaction with the input item. In this particular case the item is a movie.

# %% [markdown]
# The cells below will handle getting recommendations from the "More like X" Recommender and rendering the results. Let's see what the recommendations are for the first item we looked at earlier in this notebook (Terminator 2: Judgment Day).
#
# We will be using the `recommenderArn`, the `itemId`, the `userId` as well as the number or results we want, `numResults`.

# %%
# First pick a user
testUserId = "1"

# %%
get_recommendations_response = personalize_runtime.get_recommendations(
    recommenderArn = recommender_more_like_x_arn,
    itemId = str(589),
    userId = testUserId,
    numResults = 20
)

# %%
itemList = get_recommendations_response['itemList']
for item in itemList:
    print(get_movie_by_id(movieId=item['itemId']))
# Out:
# Speed (1994)
# Terminator, The (1984)
# Independence Day (a.k.a. ID4) (1996)
# Toy Story (1995)
# Lion King, The (1994)
# Mask, The (1994)
# Braveheart (1995)
# Seven (a.k.a. Se7en) (1995)
# Firm, The (1993)
# Matrix, The (1999)
# Star Wars: Episode VI - Return of the Jedi (1983)
# Die Hard (1988)
# Fugitive, The (1993)
# Interview with the Vampire: The Vampire Chronicles (1994)
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# Jurassic Park (1993)
# Usual Suspects, The (1995)
# Aliens (1986)
# True Lies (1994)
# Mrs. Doubtfire (1993)

# %% [markdown]
# Congrats, this is your first list of recommendations! This list is fine, but it would be better to see the recommendations for similar movies render in a nice dataframe. Again, let's create a helper function to achieve this.

# %%
# Update DF rendering
pd.set_option('display.max_rows', 30)

def get_new_recommendations_df(recommendations_df, movie_id, user_id):
    # Get the movie name
    movie_name = get_movie_by_id(movie_id)
    # Get the recommendations
    get_recommendations_response = personalize_runtime.get_recommendations(
        recommenderArn = recommender_more_like_x_arn,
        itemId = str(movie_id),
        userId = user_id
    )
    # Build a new dataframe of recommendations
    itemList = get_recommendations_response['itemList']
    recommendation_list = []
    for item in itemList:
        movie = get_movie_by_id(item['itemId'])
        recommendation_list.append(movie)
    new_rec_df = pd.DataFrame(recommendation_list, columns = [movie_name])
    # Add this dataframe to the old one
    recommendations_df = pd.concat([recommendations_df, new_rec_df], axis=1)
    return recommendations_df

# %% [markdown]
# Now, let's test the helper function with several different movies. Let's sample some data from our dataset to test our "More like X" Recommender. Grab 5 random movies from our dataframe.
#
# Note: We are going to show similar titles, so you may want to re-run the sample until you recognize some of the movies listed

# %%
samples = items_df.sample(5)
samples
# Out:
#                                                title
# movieId
# 148731                               La Sfida (1958)
# 65614                       Island in the Sun (1957)
# 161752   Ernst ThÃ¤lmann - Sohn seiner Klasse (1954)
# 5086                     Five Heartbeats, The (1991)
# 104542                                Joyride (1997)

# %%
more_like_x_recommendations_df = pd.DataFrame()
movies = samples.index.tolist()

for movie in movies:
    more_like_x_recommendations_df = get_new_recommendations_df(more_like_x_recommendations_df, movie, testUserId)

more_like_x_recommendations_df
# Out:
#                                       La Sfida (1958)  \
# 0              Rudolph, the Red-Nosed Reindeer (1964)
# 1                      Invitation to the Dance (1956)
# 2                             Yellow Submarine (1968)
# 3                               Shinbone Alley (1970)
# 4                                         Head (1968)
# 5                                  Blue Hawaii (1961)
# 6                             Finian's Rainbow (1968)
# 7              Seven Brides for Seven Brothers (1954)
# 8                                  Animal Farm (1954)
# 9   Wonderful World of the Brothers Grimm, The (1962)
# 10                             Daddy Long Legs (1955)
# 11             How the Grinch Stole Christmas! (1966)
# 12                              The Snow Queen (1957)
# 13                    Donald in Mathmagic Land (1959)
# 14                     Chitty Chitty Bang Bang (1968)
# 15                                      Kismet (1955)
# 16                       Zakoldovannyy Malchik (1955)
# 17        Vovka in the Kingdom of Far Far Away (1965)
# 18                                    Carousel (1956)
# 19                                  Thumbelina (1954)
# 20                   The Bremen Town Musicians (1969)
# 21                       Belladonna of Sadness (1973)
# 22                                   Brigadoon (1954)
# 23                           Gnome-Mobile, The (1967)
# 24                          Allegro non troppo (1977)
#
#                              Island in the Sun (1957)  \
# 0                                        Julia (1977)
# 1                              King and I, The (1956)
# 2                              West Side Story (1961)
# 3                                       Lolita (1962)
# 4   Umbrellas of Cherbourg, The (Parapluies de Che...
# 5              Breathless (Ã bout de souffle) (1960)
# 6                                    Brigadoon (1954)
# 7                                        Marty (1955)
# 8                               Guys and Dolls (1955)
# 9   Woman Is a Woman, A (femme est une femme, Une)...
# 10                              Red Shoes, The (1948)
# 11                               South Pacific (1958)
# 12                 Black Orpheus (Orfeu Negro) (1959)
# 13              Avventura, L' (Adventure, The) (1960)
# 14                               Hello, Dolly! (1969)
# 15                Jules and Jim (Jules et Jim) (1961)
# 16                             Daddy Long Legs (1955)
# 17                               Women in Love (1969)
# 18                         Hard Day's Night, A (1964)
# 19                                   Cleopatra (1963)
# 20                            Harold and Maude (1971)
# 21                                        Gigi (1958)
# 22                                 Pillow Talk (1959)
# 23                      All That Heaven Allows (1955)
# 24                                  Funny Girl (1968)
#
#           Ernst ThÃ¤lmann - Sohn seiner Klasse (1954)  \
# 0      Ernst ThÃ¤lmann - FÃ¼hrer seiner Klasse (1955)
# 1                                       Kismet (1955)
# 2                              A Hill in Korea (1956)
# 3                                    Privilege (1967)
# 4                        I Could Go on Singing (1963)
# 5                            All Hands on Deck (1961)
# 6                                  Kid Galahad (1962)
# 7                               Narrien illat (1970)
# 8                        High Time (Big Daddy) (1960)
# 9                              Under Ten Flags (1960)
# 10                                   Rogue Cop (1954)
# 11                             Sincerely Yours (1955)
# 12            Joker Is Wild, The (All the Way) (1957)
# 13                          Interrupted Melody (1955)
# 14  Counterfeit Coin, The (Istoria mias kalpikis l...
# 15                          Satan Never Sleeps (1962)
# 16                             Beloved Infidel (1959)
# 17  Black Tights (1-2-3-4 ou Les Collants noirs) (...
# 18                                      Athena (1954)
# 19                         Silver Chalice, The (1954)
# 20                       Love is My Profession (1958)
# 21                                  April Love (1957)
# 22                           Hollywood or Bust (1956)
# 23                             Fraulein Doktor (1969)
# 24                        I Was Monty's Double (1958)
#
#                   Five Heartbeats, The (1991)  \
# 0                         Carmen Jones (1954)
# 1                            Zoolander (2001)
# 2                               Selena (1997)
# 3              Amazing Spider-Man, The (2012)
# 4                             Soul Man (1986)
# 5                  Akeelah and the Bee (2006)
# 6                            Tombstone (1993)
# 7           Richard Pryor Here and Now (1983)
# 8                             Breakout (1975)
# 9                       Maria's Lovers (1984)
# 10                        Forrest Gump (1994)
# 11           Shawshank Redemption, The (1994)
# 12                   Coming to America (1988)
# 13                        Moulin Rouge (2001)
# 14                  Look Who's Talking (1989)
# 15                          Green Card (1990)
# 16  Police Academy 3: Back in Training (1986)
# 17                           Footloose (1984)
# 18                      Kate & Leopold (2001)
# 19                    Blue Lagoon, The (1980)
# 20                   Beautiful Mind, A (2001)
# 21              Jesus Christ Superstar (1973)
# 22                           Labyrinth (1986)
# 23                            Cocktail (1988)
# 24                         Wall Street (1987)
#
#                                      Joyride (1997)
# 0              VeggieTales: Very Silly Songs (1997)
# 1           Encounter in the Third Dimension (1999)
# 2                    General's Daughter, The (1999)
# 3                                    Asunder (1998)
# 4   Geography of Fear, The (Pelon maantiede) (2000)
# 5                              Intruder, The (1999)
# 6                        Cenizas del Paraiso (1997)
# 7                                    'R Xmas (2001)
# 8                   Let The Devil Wear Black (1999)
# 9                                 Dead Heart (1996)
# 10             Curve, The (Dead Man's Curve) (1998)
# 11                                    Deeply (2000)
# 12                          Johnny Skidmarks (1998)
# 13     Between Your Legs (Entre las piernas) (1999)
# 14                     Letters from a Killer (1998)
# 15                         Moonlight Express (1999)
# 16                        The Wyvern Mystery (2000)
# 17                         Christina's House (2000)
# 18                             Here on Earth (2000)
# 19                                   Tempted (2001)
# 20            This World, Then the Fireworks (1997)
# 21                            Hostile Waters (1997)
# 22                                  Legalese (1998)
# 23                                 The Maker (1997)
# 24                         Evidence of Blood (1998)

# %% [markdown]
# You may notice that some of the items look the same, hopefully not all of them do (this is more likely with a smaller # of interactions, which will be more common with the movielens small dataset).

# %% [markdown]
# ### "Top picks for you" Recommender
#
# "Top picks for you" supports personalization of the items for a specific user based on their past behavior and can intake real time events in order to alter recommendations for a user without retraining.
#
# Since "Top picks for you" relies on having a sampling of users, let's load the data we need for that and select 3 random users. Since Movielens does not include user data, we will select 3 random numbers from the range of user id's in the dataset.

# %%
if not USE_FULL_MOVIELENS:
    users = random.sample(range(1, 600), 3)
else:
    users = random.sample(range(1, 162000), 3)
users
# Out:
# [28783, 84713, 109510]

# %% [markdown]
# Now we render the recommendations for our 3 random users from above. After that, we will explore real-time interactions before moving on to Personalized Ranking.
#
# "Top picks for you" requires only a user as input, and it will return items that are relevant for that particular user. In this particular case the item is a movie.
#
# The cells below will handle getting recommendations from the "Top picks for you" Recommender and rendering the results.
#
# We will be using the `recommenderArn`, the `userId` as well as the number or results we want, `numResults`.
#
# Again, we create a helper function to render the results in a nice dataframe.
#
# #### API call results

# %%
# Update DF rendering
pd.set_option('display.max_rows', 30)

def get_new_recommendations_df_users(recommendations_df, user_id):
    # Get the movie name
    #movie_name = get_movie_by_id(artist_ID)
    # Get the recommendations
    get_recommendations_response = personalize_runtime.get_recommendations(
        recommenderArn = recommender_top_picks_arn,
        userId = str(user_id),
        numResults = 20
    )
    # Build a new dataframe of recommendations
    itemList = get_recommendations_response['itemList']
    recommendation_list = []
    for item in itemList:
        movie = get_movie_by_id(item['itemId'])
        recommendation_list.append(movie)
    new_rec_df = pd.DataFrame(recommendation_list, columns = [user_id])
    # Add this dataframe to the old one
    recommendations_df = pd.concat([recommendations_df, new_rec_df], axis=1)
    return recommendations_df

# %%
recommendations_df_users = pd.DataFrame()

for user in users:
    recommendations_df_users = get_new_recommendations_df_users(recommendations_df_users, user)

recommendations_df_users
# Out:
#                                        28783   \
# 0                  Grosse Pointe Blank (1997)
# 1           O Brother, Where Art Thou? (2000)
# 2                   Dazed and Confused (1993)
# 3                         Forrest Gump (1994)
# 4         Monty Python's Life of Brian (1979)
# 5                      Raising Arizona (1987)
# 6                             Rushmore (1998)
# 7                        Groundhog Day (1993)
# 8                   This Is Spinal Tap (1984)
# 9                         Best in Show (2000)
# 10  Monty Python's The Meaning of Life (1983)
# 11                       Pleasantville (1998)
# 12                Being John Malkovich (1999)
# 13     Monty Python and the Holy Grail (1975)
# 14                       High Fidelity (2000)
# 15                         Wag the Dog (1997)
# 16                       Bottle Rocket (1996)
# 17                Hudsucker Proxy, The (1994)
# 18                         Top Secret! (1984)
# 19        There's Something About Mary (1998)
#
#                              84713   \
# 0          On the Waterfront (1954)
# 1            His Girl Friday (1940)
# 2                  Stalag 17 (1953)
# 3                 Casablanca (1942)
# 4      It Happened One Night (1934)
# 5           Double Indemnity (1944)
# 6                  Key Largo (1948)
# 7           Some Like It Hot (1959)
# 8    Philadelphia Story, The (1940)
# 9               Modern Times (1936)
# 10         Wizard of Oz, The (1939)
# 11             All About Eve (1950)
# 12              Hustler, The (1961)
# 13                 Duck Soup (1933)
# 14           American Beauty (1999)
# 15  In the Heat of the Night (1967)
# 16               City Lights (1931)
# 17     To Kill a Mockingbird (1962)
# 18             Graduate, The (1967)
# 19        North by Northwest (1959)
#
#                                                109510
# 0                         Love & Human Remains (1993)
# 1   In the Realm of the Senses (Ai no corrida) (1976)
# 2                                        Nadja (1994)
# 3                                        Naked (1993)
# 4                                      Exotica (1994)
# 5                                  Killing Zoe (1994)
# 6                                      Amateur (1994)
# 7                                 Strange Days (1995)
# 8                                        Faces (1968)
# 9            Beauty of the Day (Belle de jour) (1967)
# 10                           Romeo Is Bleeding (1993)
# 11                              Body Snatchers (1993)
# 12                                  Four Rooms (1995)
# 13                           Ladybird Ladybird (1994)
# 14                               Little Odessa (1994)
# 15                       Kicking and Screaming (1995)
# 16                        What Happened Was... (1994)
# 17                                    Dead Man (1995)
# 18                                 Bitter Moon (1992)
# 19          Mrs. Parker and the Vicious Circle (1994)

# %% [markdown]
# Here we clearly see that the recommendations for each user are different. If you were to need a cache for these results, you could start by running the API calls through all your users and store the results, or you could use a batch export, which will be covered later in this notebook.

# %% [markdown]
# ## Interact with Campaigns <a class="anchor" id="interact-campaigns"></a>
# [Back to top](#top)
#
# Now that the reranking campaign is deployed and active, we can start to get recommendations via an API call.

# %% [markdown]
# ### Personalized Ranking
#
# The core use case for personalized ranking is to take a collection of items and to render them in priority or probable order of interest for a user. For a VOD application you want dynamically render a personalized shelf/rail/carousel based on some information (director, location, superhero franchise, movie time period, etc...). This may not be information that you have in your metadata, so an item metadata filter will not work, however you may have this information within you system to generate the item list.
#
# To demonstrate this, we will use the same user from before and a random collection of items.

# %%
rerank_user = user
rerank_items = items_df.sample(25).index.tolist()

# %% [markdown]
# Now build a nice dataframe that shows the input data.

# %%
rerank_list = []
for item in rerank_items:
    movie = get_movie_by_id(item)
    rerank_list.append(movie)
rerank_df = pd.DataFrame(rerank_list, columns = ['Un-Ranked'])
rerank_df
# Out:
#                                             Un-Ranked
# 0                    Princess for Christmas, A (2011)
# 1         Enron: The Smartest Guys in the Room (2005)
# 2               Man There Was, A (Terje Vigen) (1917)
# 3                                The Outriders (1950)
# 4                           Stonewall Uprising (2010)
# 5                              Zero Years, The (2005)
# 6                                Evil Thoughts (1976)
# 7                                  Saint Maybe (1998)
# 8                                        Zenda (2009)
# 9                          Les Loups entre eux (1985)
# 10                          Operation Daybreak (1975)
# 11                       Once Upon a Honeymoon (1942)
# 12                            The General Line (1929)
# 13  Sometimes Happiness, Sometimes Sorrow (Kabhi K...
# 14                                  Tank Force (1958)
# 15                           American Pastoral (2016)
# 16                                    Consumed (2015)
# 17              The Seashell and the Clergyman (1928)
# 18                       Talk About a Stranger (1952)
# 19                               Crooked House (2017)
# 20                     Shriek of the Mutilated (1974)
# 21                              Ora o mai piÃ¹ (2003)
# 22                               Never Forever (2007)
# 23                           Secret Agent, The (1996)
# 24                                     8 Dates (2008)

# %% [markdown]
# Then make the personalized ranking API call.

# %%
rerank_item_list = []
for item in rerank_items:
    rerank_item_list.append(str(item))
    
# Get recommended reranking
get_recommendations_response_rerank = personalize_runtime.get_personalized_ranking(
        campaignArn = rerank_campaign_arn,
        userId = str(rerank_user),
        inputList = rerank_item_list
)

# %% [markdown]
# Now add the reranked items as a second column to the original dataframe, for a side-by-side comparison.

# %%
ranked_list = []
item_list = get_recommendations_response_rerank['personalizedRanking']
for item in item_list:
    movie = get_movie_by_id(item['itemId'])
    ranked_list.append(movie)
ranked_df = pd.DataFrame(ranked_list, columns = ['Re-Ranked'])
rerank_df = pd.concat([rerank_df, ranked_df], axis=1)
rerank_df
# Out:
#                                             Un-Ranked  \
# 0                    Princess for Christmas, A (2011)
# 1         Enron: The Smartest Guys in the Room (2005)
# 2               Man There Was, A (Terje Vigen) (1917)
# 3                                The Outriders (1950)
# 4                           Stonewall Uprising (2010)
# 5                              Zero Years, The (2005)
# 6                                Evil Thoughts (1976)
# 7                                  Saint Maybe (1998)
# 8                                        Zenda (2009)
# 9                          Les Loups entre eux (1985)
# 10                          Operation Daybreak (1975)
# 11                       Once Upon a Honeymoon (1942)
# 12                            The General Line (1929)
# 13  Sometimes Happiness, Sometimes Sorrow (Kabhi K...
# 14                                  Tank Force (1958)
# 15                           American Pastoral (2016)
# 16                                    Consumed (2015)
# 17              The Seashell and the Clergyman (1928)
# 18                       Talk About a Stranger (1952)
# 19                               Crooked House (2017)
# 20                     Shriek of the Mutilated (1974)
# 21                              Ora o mai piÃ¹ (2003)
# 22                               Never Forever (2007)
# 23                           Secret Agent, The (1996)
# 24                                     8 Dates (2008)
#
#                                             Re-Ranked
# 0                            Secret Agent, The (1996)
# 1                          Les Loups entre eux (1985)
# 2   Sometimes Happiness, Sometimes Sorrow (Kabhi K...
# 3                        Talk About a Stranger (1952)
# 4                        Once Upon a Honeymoon (1942)
# 5               Man There Was, A (Terje Vigen) (1917)
# 6                             The General Line (1929)
# 7               The Seashell and the Clergyman (1928)
# 8                                Evil Thoughts (1976)
# 9         Enron: The Smartest Guys in the Room (2005)
# 10                             Zero Years, The (2005)
# 11                               Never Forever (2007)
# 12                          Operation Daybreak (1975)
# 13                               The Outriders (1950)
# 14                          Stonewall Uprising (2010)
# 15                     Shriek of the Mutilated (1974)
# 16                              Ora o mai piÃ¹ (2003)
# 17                                     8 Dates (2008)
# 18                           American Pastoral (2016)
# 19                                 Saint Maybe (1998)
# 20                                    Consumed (2015)
# 21                   Princess for Christmas, A (2011)
# 22                               Crooked House (2017)
# 23                                  Tank Force (1958)
# 24                                       Zenda (2009)

# %% [markdown]
# You can see above how each entry was re-ordered based on the model's understanding of the user. This is a popular task when you have a collection of items to surface a user, a list of promotions for example.

# %% [markdown]
# ## Using Static and Dynamic Filters <a class="anchor" id="filters"></a>
# [Back to top](#top)
#
# Lets interact with the static filters we created in the previous notebook, and utilize dynamic filters in realtime.
#
# A few common use cases for dynamic filters in Video On Demand are:
#
# Categorical filters based on Item Metadata (that arent range based) - Often your item metadata will have information about the title such as Genre, Keyword, Year, Director, Actor etc. Filtering on these can provide recommendations within that data, such as action movies, Steven Spielberg movies, Movies from 1995 etc.
#
# Events - you may want to filter out certain events and provide results based on those events, such as moving a title from a "suggestions to watch" recommendation to a "watch again" recommendations.

# %% [markdown]
# Now lets apply item filters to see recommendations for one of these users within each decade of our static filters.

# %%
def get_new_recommendations_df_by_static_filter(recommendations_df, user_id, filter_arn):
    # Get the recommendations
    get_recommendations_response = personalize_runtime.get_recommendations(
        recommenderArn = recommender_top_picks_arn,
        userId = str(user_id),
        filterArn = filter_arn
    )
    # Build a new dataframe of recommendations
    item_list = get_recommendations_response['itemList']
    recommendation_list = []
    for item in item_list:
        movie = get_movie_by_id(item['itemId'])
        recommendation_list.append(movie)
    #print(recommendation_list)
    filter_name = filter_arn.split('/')[1]
    new_rec_DF = pd.DataFrame(recommendation_list, columns = [filter_name])
    # Add this dataframe to the old one
    recommendations_df = pd.concat([recommendations_df, new_rec_DF], axis=1)
    return recommendations_df

# %%
def get_new_recommendations_df_by_dynamic_filter(recommendations_df, user_id, genre_filter_arn, filter_values):
    # Get the recommendations
    get_recommendations_response = personalize_runtime.get_recommendations(
        recommenderArn = recommender_top_picks_arn,
        userId = str(user_id),
        filterArn = genre_filter_arn,
        filterValues = { "GENRE": "\"" + filter_values + "\""}
    )
    # Build a new dataframe of recommendations
    item_list = get_recommendations_response['itemList']
    recommendation_list = []
    for item in item_list:
        movie = get_movie_by_id(item['itemId'])
        recommendation_list.append(movie)
    filter_name = genre_filter_arn.split('/')[1]
    new_rec_DF = pd.DataFrame(recommendation_list, columns = [filter_values])
    # Add this dataframe to the old one
    recommendations_df = pd.concat([recommendations_df, new_rec_DF], axis=1)
    return recommendations_df

# %% [markdown]
# You can see the recommendations for movies within a given decade. Within a VOD application you could create Shelves (also known as rails or carousels) easily by using these filters. Depending on the information you have about your items, You could also filter on additional information such as keyword, year/decade etc.

# %%
recommendations_df_decade_shelves = pd.DataFrame()
for filter_arn in meta_filter_decade_arns:
    recommendations_df_decade_shelves = get_new_recommendations_df_by_static_filter(recommendations_df_decade_shelves, user, filter_arn)

recommendations_df_decade_shelves
# Out:
#                                                 1950s  \
# 0   Ballad of Narayama, The (Narayama Bushiko) (1958)
# 1                 20,000 Leagues Under the Sea (1954)
# 2                            Dial M for Murder (1954)
# 3              World of Apu, The (Apur Sansar) (1959)
# 4   Eyes Without a Face (Yeux sans visage, Les) (1...
# 5                        Rebel Without a Cause (1955)
# 6    Song of the Little Road (Pather Panchali) (1955)
# 7                Unvanquished, The (Aparajito) (1957)
# 8                    Streetcar Named Desire, A (1951)
# 9                                  Rear Window (1954)
# 10        Seven Samurai (Shichinin no samurai) (1954)
# 11                                  Cinderella (1950)
# 12                         Alice in Wonderland (1951)
# 13                                     Vertigo (1958)
# 14                    Old Man and the Sea, The (1958)
# 15                                12 Angry Men (1957)
# 16    Seventh Seal, The (Sjunde inseglet, Det) (1957)
# 17                                   Blob, The (1958)
# 18                                  Old Yeller (1957)
# 19                                         Kim (1950)
# 20                          North by Northwest (1959)
# 21                            Forbidden Planet (1956)
# 22                                       Giant (1956)
# 23                              Paths of Glory (1957)
# 24                                  Pickpocket (1959)
#
#                                                 1960s  \
# 0                                        Faces (1968)
# 1            Beauty of the Day (Belle de jour) (1967)
# 2                   Purple Noon (Plein soleil) (1960)
# 3   Umbrellas of Cherbourg, The (Parapluies de Che...
# 4                             Bonnie and Clyde (1967)
# 5   Dr. Strangelove or: How I Learned to Stop Worr...
# 6                        2001: A Space Odyssey (1968)
# 7                                   Barbarella (1968)
# 8                          Spirits of the Dead (1968)
# 9                      Sword in the Stone, The (1963)
# 10                                Mary Poppins (1964)
# 11                         Sound of Music, The (1965)
# 12  Good, the Bad and the Ugly, The (Buono, il bru...
# 13        Winnie the Pooh and the Blustery Day (1968)
# 14                      Contempt (MÃ©pris, Le) (1963)
# 15  2 ou 3 choses que je sais d'elle (2 or 3 Thing...
# 16                                      Psycho (1960)
# 17                               Love Bug, The (1969)
# 18                Faster Pussycat! Kill! Kill! (1965)
# 19                                 8 1/2 (8Â½) (1963)
# 20  Once Upon a Time in the West (C'era una volta ...
# 21                                   Cape Fear (1962)
# 22                               Graduate, The (1967)
# 23                    Night of the Living Dead (1968)
# 24                                      Lolita (1962)
#
#                                                 1970s  \
# 0   In the Realm of the Senses (Ai no corrida) (1976)
# 1                               Candidate, The (1972)
# 2           Star Wars: Episode IV - A New Hope (1977)
# 3      Bread and Chocolate (Pane e cioccolata) (1973)
# 4                 Monty Python's Life of Brian (1979)
# 5                          Clockwork Orange, A (1971)
# 6          Willy Wonka & the Chocolate Factory (1971)
# 7                            Ruling Class, The (1972)
# 8            Tin Drum, The (Blechtrommel, Die) (1979)
# 9                               Godfather, The (1972)
# 10                             Aristocats, The (1970)
# 11             Monty Python and the Holy Grail (1975)
# 12  Garden of the Finzi-Continis, The (Giardino de...
# 13                                   Walkabout (1971)
# 14                         Switchblade Sisters (1975)
# 15                                     Sleeper (1973)
# 16                                     Bananas (1971)
# 17                              Apocalypse Now (1979)
# 18                                   Chinatown (1974)
# 19                                       Alien (1979)
# 20                          Herbie Rides Again (1974)
# 21             One Flew Over the Cuckoo's Nest (1975)
# 22                Autumn Sonata (HÃ¶stsonaten) (1978)
# 23                               Pete's Dragon (1977)
# 24                    Escape to Witch Mountain (1975)
#
#                                                 1980s  \
# 0                                 Blade Runner (1982)
# 1                Coup de torchon (Clean Slate) (1981)
# 2                         Fish Called Wanda, A (1988)
# 3                                  Heavy Metal (1981)
# 4                                     Die Hard (1988)
# 5                                       Brazil (1985)
# 6                                        Akira (1988)
# 7   Star Wars: Episode VI - Return of the Jedi (1983)
# 8     Cook the Thief His Wife & Her Lover, The (1989)
# 9                   E.T. the Extra-Terrestrial (1982)
# 10                                Paris, Texas (1984)
# 11                                     Top Gun (1986)
# 12  Raiders of the Lost Ark (Indiana Jones and the...
# 13                            Shadows (Cienie) (1988)
# 14  Star Wars: Episode V - The Empire Strikes Back...
# 15                           Full Metal Jacket (1987)
# 16                         Blues Brothers, The (1980)
# 17                       Boot, Das (Boat, The) (1981)
# 18                                      Batman (1989)
# 19                                     Platoon (1986)
# 20                             Victor/Victoria (1982)
# 21                                      Aliens (1986)
# 22                             Terminator, The (1984)
# 23                                 Down by Law (1986)
# 24                            Oliver & Company (1988)
#
#                                                 1990s  \
# 0                         Love & Human Remains (1993)
# 1                                        Nadja (1994)
# 2                                        Naked (1993)
# 3                                      Exotica (1994)
# 4                                  Killing Zoe (1994)
# 5                                      Amateur (1994)
# 6                                 Strange Days (1995)
# 7                            Romeo Is Bleeding (1993)
# 8                               Body Snatchers (1993)
# 9                                   Four Rooms (1995)
# 10                           Ladybird Ladybird (1994)
# 11                               Little Odessa (1994)
# 12                       Kicking and Screaming (1995)
# 13                        What Happened Was... (1994)
# 14                                    Dead Man (1995)
# 15                                 Bitter Moon (1992)
# 16          Mrs. Parker and the Vicious Circle (1994)
# 17                            Blue in the Face (1995)
# 18                               Kiss of Death (1995)
# 19                                  Kalifornia (1993)
# 20                                    Clockers (1995)
# 21  City of Lost Children, The (CitÃ© des enfants ...
# 22                        Swimming with Sharks (1995)
# 23                  Killer (Bulletproof Heart) (1994)
# 24                                      Casino (1995)
#
#                                                 2000s  \
# 0                             Dark Knight, The (2008)
# 1   Lord of the Rings: The Fellowship of the Ring,...
# 2   Code Unknown (Code inconnu: RÃ©cit incomplet d...
# 3                      Little Otik (OtesÃ¡nek) (2000)
# 4                                      Chopper (2000)
# 5                                 Donnie Darko (2001)
# 6                                     3 Nights (2001)
# 7        Eternal Sunshine of the Spotless Mind (2004)
# 8   Joint Security Area (Gongdong gyeongbi guyeok ...
# 9                                      Memento (2000)
# 10                            Isle, The (Seom) (2000)
# 11  Amelie (Fabuleux destin d'AmÃ©lie Poulain, Le)...
# 12              101 Reykjavik (101 ReykjavÃ­k) (2000)
# 13                                       Bully (2001)
# 14                               No Such Thing (2001)
# 15  Man Without a Past, The (Mies vailla menneisyy...
# 16  Lord of the Rings: The Return of the King, The...
# 17                            What Girls Learn (2001)
# 18                        Visitor Q (Bizita Q) (2001)
# 19                                   Dark Days (2000)
# 20                                      Hunger (2001)
# 21                         Requiem for a Dream (2000)
# 22                                    21 Grams (2003)
# 23                                      Snatch (2000)
# 24                               FÃ¶delsedagen (2000)
#
#                                                 2010s
# 0                                    Inception (2010)
# 1                                     Ad Astra (2019)
# 2                                       Rubber (2010)
# 3   Uncle Boonmee Who Can Recall His Past Lives (L...
# 4                    It's Such a Beautiful Day (2012)
# 5                                    Unrivaled (2010)
# 6                      Dragged Across Concrete (2018)
# 7                                Africa United (2010)
# 8                        Under the Silver Lake (2018)
# 9                          Tomorrow Ever After (2017)
# 10                              Shoot the Hero (2010)
# 11                                        Prey (2010)
# 12                         Ninjas vs. Vampires (2010)
# 13                                   Douchebag (2010)
# 14         Heartbeats (Les amours imaginaires) (2010)
# 15                               The Lion King (2019)
# 16               Here Comes the Bride, My Mom! (2010)
# 17          Grandmaster, The (Yi dai zong shi) (2013)
# 18                                 Holy Motors (2012)
# 19                                    Parasite (2019)
# 20                                     Aladdin (2019)
# 21                           Truth About Kerry (2010)
# 22              Cold Fish (Tsumetai nettaigyo) (2010)
# 23                                Chronic Town (2010)
# 24                                       Eamon (2010)

# %%
# Create a dataframe for the items by reading in the correct source CSV
items_meta_df = pd.read_csv(data_dir + '/item-meta.csv', sep=',', index_col=0)

# Render some sample data
items_meta_df.head(10)
# Out:
#                                               GENRES  YEAR  CREATION_TIMESTAMP
# ITEM_ID
# 1        Adventure|Animation|Children|Comedy|Fantasy  1995          1640995200
# 2                         Adventure|Children|Fantasy  1995          1640995200
# 3                                     Comedy|Romance  1995          1640995200
# 4                               Comedy|Drama|Romance  1995          1640995200
# 5                                             Comedy  1995          1640995200
# 6                              Action|Crime|Thriller  1995          1640995200
# 7                                     Comedy|Romance  1995          1640995200
# 8                                 Adventure|Children  1995          1640995200
# 9                                             Action  1995          1640995200
# 10                         Action|Adventure|Thriller  1995          1640995200

# %% [markdown]
# Now what we want to do is determine the genres to filter on, for that we need a list of all genres. First we will get all the unique values of the column GENRE, then split strings on | if they exist, everyone will then get added to a long list which will be converted to a set for efficiency. That set will then be made into a list so that it can be iterated, and we can then use the get recommendatioins API.

# %%
unique_genre_field_values = items_meta_df['GENRES'].unique()

genre_val_list = []

def process_for_bar_char(val, val_list):
    if '|' in val:
        values = val.split('|')
        for item in values:
            val_list.append(item)
    elif '(' in val:
        pass
    else:
        val_list.append(val)
    return val_list
    

for val in unique_genre_field_values:
    genre_val_list = process_for_bar_char(val, genre_val_list)

genres_to_filter = list(set(genre_val_list))

# %%
genres_to_filter
# Out:
# ['Action',
#  'Sci-Fi',
#  'Fantasy',
#  'Musical',
#  'Comedy',
#  'War',
#  'Romance',
#  'Mystery',
#  'Film-Noir',
#  'Drama',
#  'Thriller',
#  'Crime',
#  'Children',
#  'Adventure',
#  'Western',
#  'IMAX',
#  'Documentary',
#  'Animation',
#  'Horror']

# %%
# Iterate through Genres
recommendations_df_genre_shelves = pd.DataFrame()
for genre in genres_to_filter:
    recommendations_df_genre_shelves = get_new_recommendations_df_by_dynamic_filter(recommendations_df_genre_shelves, user, genre_filter_arn , genre)
    
recommendations_df_genre_shelves
# Out:
#                                                Action  \
# 0                                 Strange Days (1995)
# 1                                 Blade Runner (1982)
# 2                                    Crow, The (1994)
# 3           Star Wars: Episode IV - A New Hope (1977)
# 4                                  Bad Company (1995)
# 5                              Dead Presidents (1995)
# 6                          From Dusk Till Dawn (1996)
# 7                                    Screamers (1995)
# 8                                  Heavy Metal (1981)
# 9                         Hot Shots! Part Deux (1993)
# 10                                 Hard Target (1993)
# 11                          Lawnmower Man, The (1992)
# 12                                   Desperado (1995)
# 13                                      Eraser (1996)
# 14                                 Dragonheart (1996)
# 15                           Menace II Society (1993)
# 16                         Crossing Guard, The (1995)
# 17                           Terminal Velocity (1994)
# 18                   Crow: City of Angels, The (1996)
# 19                                    Die Hard (1988)
# 20                  Terminator 2: Judgment Day (1991)
# 21                               Jurassic Park (1993)
# 22  Highlander III: The Sorcerer (a.k.a. Highlande...
# 23                            Escape from L.A. (1996)
# 24  Supercop (Police Story 3: Supercop) (Jing cha ...
#
#                                                Sci-Fi  \
# 0                                 Strange Days (1995)
# 1                               Body Snatchers (1993)
# 2                                 Blade Runner (1982)
# 3   City of Lost Children, The (CitÃ© des enfants ...
# 4               Visitors, The (Visiteurs, Les) (1993)
# 5           Star Wars: Episode IV - A New Hope (1977)
# 6        Ghost in the Shell (KÃ´kaku kidÃ´tai) (1995)
# 7      Mystery Science Theater 3000: The Movie (1996)
# 8                                    Screamers (1995)
# 9                          Clockwork Orange, A (1971)
# 10                                 Heavy Metal (1981)
# 11                       2001: A Space Odyssey (1968)
# 12                          Lawnmower Man, The (1992)
# 13                   Island of Dr. Moreau, The (1996)
# 14                       Village of the Damned (1995)
# 15                                  Barbarella (1968)
# 16                20,000 Leagues Under the Sea (1954)
# 17                  Terminator 2: Judgment Day (1991)
# 18                               Jurassic Park (1993)
# 19                            Escape from L.A. (1996)
# 20                                      Brazil (1985)
# 21               Independence Day (a.k.a. ID4) (1996)
# 22                                Arrival, The (1996)
# 23                                       Akira (1988)
# 24  Star Wars: Episode VI - Return of the Jedi (1983)
#
#                                               Fantasy  \
# 0   City of Lost Children, The (CitÃ© des enfants ...
# 1               Visitors, The (Visiteurs, Les) (1993)
# 2                                    Crow, The (1994)
# 3                                     Reckless (1995)
# 4              Snow White and the Seven Dwarfs (1937)
# 5          Willy Wonka & the Chocolate Factory (1971)
# 6                                  Dragonheart (1996)
# 7                                Prophecy, The (1995)
# 8                                 Lesson Faust (1994)
# 9   Highlander III: The Sorcerer (a.k.a. Highlande...
# 10                                Three Wishes (1995)
# 11             Candyman: Farewell to the Flesh (1995)
# 12                                      Brazil (1985)
# 13                     Sword in the Stone, The (1963)
# 14                   James and the Giant Peach (1996)
# 15                            Last Action Hero (1993)
# 16                                 Shadow, The (1994)
# 17                                     Orlando (1992)
# 18                                Mary Poppins (1964)
# 19                        Nutty Professor, The (1996)
# 20                  NeverEnding Story III, The (1994)
# 21             Monty Python and the Holy Grail (1975)
# 22                              Drop Dead Fred (1991)
# 23                           Super Mario Bros. (1993)
# 24                                   Mask, The (1994)
#
#                                               Musical  \
# 0   Umbrellas of Cherbourg, The (Parapluies de Che...
# 1                       Farinelli: il castrato (1994)
# 2              Snow White and the Seven Dwarfs (1937)
# 3          Willy Wonka & the Chocolate Factory (1971)
# 4                      Sword in the Stone, The (1963)
# 5                    James and the Giant Peach (1996)
# 6                                 Mary Poppins (1964)
# 7                          Sound of Music, The (1965)
# 8                                  Kansas City (1996)
# 9         Winnie the Pooh and the Blustery Day (1968)
# 10                Hunchback of Notre Dame, The (1996)
# 11                                   Pinocchio (1940)
# 12                              Lion King, The (1994)
# 13                         Blues Brothers, The (1980)
# 14              What's Love Got to Do with It? (1993)
# 15                                  Cinderella (1950)
# 16                             Victor/Victoria (1982)
# 17                         Alice in Wonderland (1951)
# 18                       Three Caballeros, The (1945)
# 19                            Oliver & Company (1988)
# 20                     All Dogs Go to Heaven 2 (1996)
# 21                                       Dumbo (1941)
# 22                    Everyone Says I Love You (1996)
# 23                               Pete's Dragon (1977)
# 24                    Bedknobs and Broomsticks (1971)
#
#                                                Comedy  \
# 0                         Love & Human Remains (1993)
# 1                                   Four Rooms (1995)
# 2                         What Happened Was... (1994)
# 3                        Kicking and Screaming (1995)
# 4                             Blue in the Face (1995)
# 5                         Swimming with Sharks (1995)
# 6                           Living in Oblivion (1995)
# 7                                Trainspotting (1996)
# 8                              Unstrung Heroes (1995)
# 9                                  Underground (1995)
# 10              Visitors, The (Visiteurs, Les) (1993)
# 11                                    Crooklyn (1994)
# 12                         I Like It Like That (1994)
# 13  Dr. Strangelove or: How I Learned to Stop Worr...
# 14                          Bhaji on the Beach (1993)
# 15                 Even Cowgirls Get the Blues (1993)
# 16     Bread and Chocolate (Pane e cioccolata) (1973)
# 17                            Mighty Aphrodite (1995)
# 18                                Mute Witness (1994)
# 19                  Destiny Turns on the Radio (1995)
# 20                                   Threesome (1994)
# 21                Monty Python's Life of Brian (1979)
# 22                               Reality Bites (1994)
# 23                                    Reckless (1995)
# 24     Mystery Science Theater 3000: The Movie (1996)
#
#                                                   War  \
# 0                                  Underground (1995)
# 1   Dr. Strangelove or: How I Learned to Stop Worr...
# 2                               Beyond Rangoon (1995)
# 3                         Hot Shots! Part Deux (1993)
# 4                                   Stalingrad (1993)
# 5         Land and Freedom (Tierra y libertad) (1995)
# 6            Tin Drum, The (Blechtrommel, Die) (1979)
# 7                                 Forrest Gump (1994)
# 8               Before the Rain (Pred dozhdot) (1994)
# 9     All Things Fair (Lust och fÃ¤gring stor) (1995)
# 10                              Canadian Bacon (1995)
# 11                           Walking Dead, The (1995)
# 12                                 Richard III (1995)
# 13                                     Bananas (1971)
# 14                              Apocalypse Now (1979)
# 15                          Courage Under Fire (1996)
# 16                            MisÃ©rables, Les (1995)
# 17                        English Patient, The (1996)
# 18                           Full Metal Jacket (1987)
# 19                       Boot, Das (Boat, The) (1981)
# 20                                     Platoon (1986)
# 21                                  Braveheart (1995)
# 22                         Legends of the Fall (1994)
# 23                                     Rob Roy (1995)
# 24                                         Ran (1985)
#
#                                               Romance  \
# 0                         What Happened Was... (1994)
# 1                                  Bitter Moon (1992)
# 2   Umbrellas of Cherbourg, The (Parapluies de Che...
# 3                    House of the Spirits, The (1993)
# 4                                     Germinal (1993)
# 5                                Total Eclipse (1995)
# 6                                      Go Fish (1994)
# 7                          I Like It Like That (1994)
# 8       Chungking Express (Chung Hing sam lam) (1994)
# 9                  Even Cowgirls Get the Blues (1993)
# 10                            Immortal Beloved (1994)
# 11                            Mighty Aphrodite (1995)
# 12                                   Threesome (1994)
# 13             Queen Margot (Reine Margot, La) (1994)
# 14                               Reality Bites (1994)
# 15                                       Heavy (1995)
# 16                  Pyromaniac's Love Story, A (1995)
# 17                Truth About Cats & Dogs, The (1996)
# 18                                Delicatessen (1991)
# 19     Things to Do in Denver When You're Dead (1995)
# 20                               Boxing Helena (1993)
# 21                              Before Sunrise (1995)
# 22                                   Desperado (1995)
# 23      Farewell My Concubine (Ba wang bie ji) (1993)
# 24                           Perez Family, The (1995)
#
#                                               Mystery  \
# 0                                 Strange Days (1995)
# 1                                     Dead Man (1995)
# 2                                     Clockers (1995)
# 3   City of Lost Children, The (CitÃ© des enfants ...
# 4       Chungking Express (Chung Hing sam lam) (1994)
# 5                        Devil in a Blue Dress (1995)
# 6                                Kaspar Hauser (1993)
# 7   Wes Craven's New Nightmare (Nightmare on Elm S...
# 8                                Boxing Helena (1993)
# 9                                Prophecy, The (1995)
# 10                           Terminal Velocity (1994)
# 11                           Dial M for Murder (1954)
# 12                         Spirits of the Dead (1968)
# 13                                 Shadow, The (1994)
# 14                              Reservoir Dogs (1992)
# 15                        Seven (a.k.a. Se7en) (1995)
# 16                                   Lone Star (1996)
# 17                          Breaking the Waves (1996)
# 18                               Unforgettable (1996)
# 19                                 Primal Fear (1996)
# 20                                     Copycat (1995)
# 21                                 Client, The (1994)
# 22                                Citizen Kane (1941)
# 23                              Basic Instinct (1992)
# 24                                  True Crime (1996)
#
#                                         Film-Noir  \
# 0                              Bitter Moon (1992)
# 1                    Devil in a Blue Dress (1995)
# 2                                   Suture (1993)
# 3                     2 Days in the Valley (1996)
# 4                             Lost Highway (1997)
# 5                                Chinatown (1974)
# 6                              Down by Law (1986)
# 7                                        M (1931)
# 8                        Miller's Crossing (1990)
# 9                            Grifters, The (1990)
# 10                          Third Man, The (1949)
# 11                               Dark City (1998)
# 12                     Maltese Falcon, The (1941)
# 13                           Touch of Evil (1958)
# 14  Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 15                          Wrong Man, The (1956)
# 16                       L.A. Confidential (1997)
# 17                       Long Goodbye, The (1973)
# 18                          One False Move (1992)
# 19                             Angel Heart (1987)
# 20                           Force of Evil (1948)
# 21                                 Hoodlum (1997)
# 22        Killing of a Chinese Bookie, The (1976)
# 23                          Big Sleep, The (1946)
# 24                            Killing, The (1956)
#
#                                                 Drama  \
# 0                         Love & Human Remains (1993)
# 1   In the Realm of the Senses (Ai no corrida) (1976)
# 2                                        Naked (1993)
# 3                                      Exotica (1994)
# 4                                      Amateur (1994)
# 5                                        Nadja (1994)
# 6                                  Killing Zoe (1994)
# 7                                 Strange Days (1995)
# 8                                        Faces (1968)
# 9            Beauty of the Day (Belle de jour) (1967)
# 10                               Little Odessa (1994)
# 11                        What Happened Was... (1994)
# 12                           Ladybird Ladybird (1994)
# 13          Mrs. Parker and the Vicious Circle (1994)
# 14                                 Bitter Moon (1992)
# 15                       Kicking and Screaming (1995)
# 16                                    Dead Man (1995)
# 17                            Blue in the Face (1995)
# 18                  Purple Noon (Plein soleil) (1960)
# 19                               Kiss of Death (1995)
# 20                                  Kalifornia (1993)
# 21                                    Clockers (1995)
# 22  City of Lost Children, The (CitÃ© des enfants ...
# 23                        Swimming with Sharks (1995)
# 24                                      Casino (1995)
#
#                                              Thriller  \
# 0                                  Killing Zoe (1994)
# 1                                      Amateur (1994)
# 2                                 Strange Days (1995)
# 3                            Romeo Is Bleeding (1993)
# 4                               Body Snatchers (1993)
# 5                         What Happened Was... (1994)
# 6                                 Blade Runner (1982)
# 7                                Kiss of Death (1995)
# 8                   Purple Noon (Plein soleil) (1960)
# 9                                   Kalifornia (1993)
# 10                  Killer (Bulletproof Heart) (1994)
# 11                        Death and the Maiden (1994)
# 12                               Red Rock West (1992)
# 13                                   Crow, The (1994)
# 14                                Mute Witness (1994)
# 15                       Devil in a Blue Dress (1995)
# 16                                      Suture (1993)
# 17                                True Romance (1993)
# 18                                      Malice (1993)
# 19                            Last Supper, The (1995)
# 20                                   Screamers (1995)
# 21                         From Dusk Till Dawn (1996)
# 22                         Clockwork Orange, A (1971)
# 23                                    Hideaway (1995)
# 24  Wes Craven's New Nightmare (Nightmare on Elm S...
#
#                                              Crime  \
# 0                                   Amateur (1994)
# 1                               Killing Zoe (1994)
# 2                              Strange Days (1995)
# 3                         Romeo Is Bleeding (1993)
# 4                             Little Odessa (1994)
# 5                Purple Noon (Plein soleil) (1960)
# 6                             Kiss of Death (1995)
# 7                                  Clockers (1995)
# 8                                    Casino (1995)
# 9                             Trainspotting (1996)
# 10                         Bonnie and Clyde (1967)
# 11                                Crow, The (1994)
# 12                    Devil in a Blue Dress (1995)
# 13            Coup de torchon (Clean Slate) (1981)
# 14                              Bad Company (1995)
# 15                       Heavenly Creatures (1994)
# 16                         The Glass Shield (1994)
# 17                             True Romance (1993)
# 18                          Dead Presidents (1995)
# 19           Young Poisoner's Handbook, The (1995)
# 20                      Clockwork Orange, A (1971)
# 21                            Jason's Lyric (1994)
# 22                     Fish Called Wanda, A (1988)
# 23  Things to Do in Denver When You're Dead (1995)
# 24                              Hard Target (1993)
#
#                                        Children  \
# 0        Snow White and the Seven Dwarfs (1937)
# 1    Willy Wonka & the Chocolate Factory (1971)
# 2        Wallace & Gromit: A Close Shave (1995)
# 3                Sword in the Stone, The (1963)
# 4              James and the Giant Peach (1996)
# 5                           Mary Poppins (1964)
# 6             NeverEnding Story III, The (1994)
# 7                        Aristocats, The (1970)
# 8                                  Fluke (1995)
# 9             E.T. the Extra-Terrestrial (1982)
# 10  Wallace & Gromit: The Wrong Trousers (1993)
# 11  Winnie the Pooh and the Blustery Day (1968)
# 12                     Super Mario Bros. (1993)
# 13                    Secret Garden, The (1993)
# 14                      Jungle Book, The (1994)
# 15          Hunchback of Notre Dame, The (1996)
# 16                      Flintstones, The (1994)
# 17                             Pinocchio (1940)
# 18                        Goofy Movie, A (1995)
# 19                        Lion King, The (1994)
# 20          Heavyweights (Heavy Weights) (1995)
# 21                            Cinderella (1950)
# 22                  Addams Family Values (1993)
# 23                         Love Bug, The (1969)
# 24                   Alice in Wonderland (1951)
#
#                                             Adventure  \
# 0   City of Lost Children, The (CitÃ© des enfants ...
# 1           Star Wars: Episode IV - A New Hope (1977)
# 2          Secret Adventures of Tom Thumb, The (1993)
# 3                               Beyond Rangoon (1995)
# 4                        2001: A Space Odyssey (1968)
# 5                                  Heavy Metal (1981)
# 6                                  Hard Target (1993)
# 7                                  Dragonheart (1996)
# 8                                Bottle Rocket (1996)
# 9                                   Barbarella (1968)
# 10                20,000 Leagues Under the Sea (1954)
# 11                       Endless Summer 2, The (1994)
# 12                               Jurassic Park (1993)
# 13                            Escape from L.A. (1996)
# 14                   James and the Giant Peach (1996)
# 15               Independence Day (a.k.a. ID4) (1996)
# 16                            Last Action Hero (1993)
# 17                                   Rock, The (1996)
# 18                                 Shadow, The (1994)
# 19               Robin Hood: Prince of Thieves (1991)
# 20                                       Akira (1988)
# 21  Star Wars: Episode VI - Return of the Jedi (1983)
# 22                              Demolition Man (1993)
# 23                  NeverEnding Story III, The (1994)
# 24                    Star Trek: First Contact (1996)
#
#                                               Western  \
# 0                                     Dead Man (1995)
# 1                 Geronimo: An American Legend (1993)
# 2                                    Desperado (1995)
# 3                                    Wild Bill (1995)
# 4                                    Bad Girls (1994)
# 5                                    Lone Star (1996)
# 6                                   Wyatt Earp (1994)
# 7                                     Maverick (1994)
# 8                                    Tombstone (1993)
# 9   Good, the Bad and the Ugly, The (Buono, il bru...
# 10                          Dances with Wolves (1990)
# 11                     Quick and the Dead, The (1995)
# 12                         Legends of the Fall (1994)
# 13  Once Upon a Time in the West (C'era una volta ...
# 14                                  Unforgiven (1992)
# 15                              Lightning Jack (1994)
# 16                             Wild Bunch, The (1969)
# 17          Butch Cassidy and the Sundance Kid (1969)
# 18  City Slickers II: The Legend of Curly's Gold (...
# 19                                       Giant (1956)
# 20                   Last of the Mohicans, The (1992)
# 21                    Apple Dumpling Gang, The (1975)
# 22                                Mariachi, El (1992)
# 23                                  Young Guns (1988)
# 24                 Back to the Future Part III (1990)
#
#                                        IMAX  \
# 0                     Lion King, The (1994)
# 1                          Apollo 13 (1995)
# 2               Beauty and the Beast (1991)
# 3                   Dark Knight, The (2008)
# 4                               More (1998)
# 5                     V for Vendetta (2006)
# 6             Across the Sea of Time (1995)
# 7                          Inception (2010)
# 8                            Everest (1998)
# 9                   Wings of Courage (1995)
# 10                  Destiny in Space (1994)
# 11             Africa: The Serengeti (1994)
# 12                     Batman Begins (2005)
# 13     T-Rex: Back to the Cretaceous (1998)
# 14                     Fantasia 2000 (1999)
# 15  Shackleton's Antarctic Adventure (2001)
# 16                          Watchmen (2009)
# 17                        All Access (2001)
# 18        Alaska: Spirit of the Wild (1997)
# 19              Matrix Reloaded, The (2003)
# 20                    Mission to Mir (1997)
# 21                            Wolves (1999)
# 22                          Titanica (1992)
# 23   Thrill Ride: The Science of Fun (1997)
# 24                           Chronos (1985)
#
#                                           Documentary  \
# 0                                        Crumb (1994)
# 1                                     Unzipped (1995)
# 2                Heidi Fleiss: Hollywood Madam (1995)
# 3                        Endless Summer 2, The (1994)
# 4                        Celluloid Closet, The (1995)
# 5       Carmen Miranda: Bananas Is My Business (1994)
# 6                                     The Show (1995)
# 7                                    Nico Icon (1995)
# 8                                  Hoop Dreams (1994)
# 9     Haunted World of Edward D. Wood Jr., The (1996)
# 10         Tigrero: A Film That Was Never Made (1994)
# 11          Marlene Dietrich: Shadow and Light (1996)
# 12  Brother Minister: The Assassination of Malcolm...
# 13  Last Klezmer: Leopold Kozlowski, His Life and ...
# 14                                     Catwalk (1996)
# 15  Microcosmos (Microcosmos: Le peuple de l'herbe...
# 16  Paradise Lost: The Child Murders at Robin Hood...
# 17                             Man of the Year (1995)
# 18                      Madonna: Truth or Dare (1991)
# 19                         Looking for Richard (1996)
# 20                       Anne Frank Remembered (1995)
# 21  Koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out ...
# 22                       Vermont Is For Lovers (1992)
# 23                          When We Were Kings (1996)
# 24                             Frank and Ollie (1995)
#
#                                             Animation  \
# 0        Ghost in the Shell (KÃ´kaku kidÃ´tai) (1995)
# 1          Secret Adventures of Tom Thumb, The (1993)
# 2                                  Heavy Metal (1981)
# 3              Snow White and the Seven Dwarfs (1937)
# 4              Wallace & Gromit: A Close Shave (1995)
# 5                                 Lesson Faust (1994)
# 6                      Sword in the Stone, The (1963)
# 7                    James and the Giant Peach (1996)
# 8                                        Akira (1988)
# 9                              Aristocats, The (1970)
# 10        Wallace & Gromit: The Wrong Trousers (1993)
# 11  Wallace & Gromit: The Best of Aardman Animatio...
# 12        Winnie the Pooh and the Blustery Day (1968)
# 13                Hunchback of Notre Dame, The (1996)
# 14                                   Pinocchio (1940)
# 15                              Goofy Movie, A (1995)
# 16                              Lion King, The (1994)
# 17                                  Cinderella (1950)
# 18                         Alice in Wonderland (1951)
# 19                                       Balto (1995)
# 20                            Oliver & Company (1988)
# 21                       Three Caballeros, The (1945)
# 22                     All Dogs Go to Heaven 2 (1996)
# 23                                       Dumbo (1941)
# 24                             Pagemaster, The (1994)
#
#                                                Horror
# 0                               Body Snatchers (1993)
# 1                                 Mute Witness (1994)
# 2                          From Dusk Till Dawn (1996)
# 3                               Addiction, The (1995)
# 4   Wes Craven's New Nightmare (Nightmare on Elm S...
# 5                                  Heavy Metal (1981)
# 6                                   Serial Mom (1994)
# 7                           Lawnmower Man, The (1992)
# 8                        Village of the Damned (1995)
# 9                                  Mary Reilly (1996)
# 10                           Lord of Illusions (1995)
# 11                               Prophecy, The (1995)
# 12                                        Wolf (1994)
# 13                         Spirits of the Dead (1968)
# 14             Candyman: Farewell to the Flesh (1995)
# 15         Cemetery Man (Dellamorte Dellamore) (1994)
# 16                         Vampire in Brooklyn (1995)
# 17  Eyes Without a Face (Yeux sans visage, Les) (1...
# 18  Mary Shelley's Frankenstein (Frankenstein) (1994)
# 19                            Frighteners, The (1996)
# 20                                     Copycat (1995)
# 21                       Hellraiser: Bloodline (1996)
# 22                                Castle Freak (1995)
# 23                         Tales from the Hood (1995)
# 24  Tales from the Crypt Presents: Demon Knight (1...

# %% [markdown]
# ## Real-time Events<a class="anchor" id="real-time"></a>
# [Back to top](#top)
#
# The next topic is real-time events. Personalize has the ability to listen to events from your application in order to update the recommendations shown to the user. This is especially useful in media workloads, like video-on-demand, where a customer's intent may differ based on if they are watching with their children or on their own.
#
# Additionally the events that are recorded via this system are stored until a delete call from you is issued, and they are used as historical data alongside the other interaction data you provided when you train your next models.
#
# Start by creating an event tracker that is attached to the dataset group. This event tracker will add information to the dataset and will influence the recommendations.

# %%
response = personalize.create_event_tracker(
    name='MovieTracker',
    datasetGroupArn=dataset_group_arn
)
print(response['eventTrackerArn'])
print(response['trackingId'])
trackingId = response['trackingId']
event_tracker_arn = response['eventTrackerArn']
# Out:
# arn:aws:personalize:us-east-1:061703360474:event-tracker/f216494c
# ed187352-b361-4cc0-8fe0-3a8fb5e369a7

# %% [markdown]
# We will create some code that simulates a user interacting with a particular item. After running this code, you will get recommendations that differ from the results above.
#
# We start by creating some methods for the simulation of real time events.

# %%
sessionDict = {}

def send_movie_click(userId, itemId, eventType):
    """
    Simulates a click as an envent
    to send an event to Amazon Personalize's Event Tracker
    """
    # Configure Session
    try:
        sessionId = sessionDict[str(userId)]
    except:
        sessionDict[str(userId)] = str(uuid.uuid1())
        sessionId = sessionDict[str(userId)]
        
    # Configure Properties:
    event = {
    "itemId": str(itemId),
    }
    event_json = json.dumps(event)
        
    # Make Call
    
    personalize_events.put_events(
    trackingId = trackingId,
    userId= str(userId),
    sessionId = sessionId,
    eventList = [{
        'sentAt': int(time.time()),
        'eventType': str(eventType),
        'properties': event_json
        }]
    )

def get_new_recommendations_df_users_real_time(recommendations_df, userId, itemId, eventType):
    # Get the artist name (header of column)
    movieName = get_movie_by_id(itemId)
    
    # Interact with different movies
    print('sending event ' + eventType + ' for ' + get_movie_by_id(itemId))
    send_movie_click(userId=userId, itemId=itemId,eventType=eventType)
    # Get the recommendations (note you should have a base recommendation DF created before)
    get_recommendations_response = personalize_runtime.get_recommendations(
        recommenderArn = recommender_top_picks_arn,
        userId = str(userId),
    )
    # Build a new dataframe of recommendations
    itemList = get_recommendations_response['itemList']
    recommendation_list = []
    for item in itemList:
        artist = get_movie_by_id(item['itemId'])
        recommendation_list.append(artist)
    new_rec_df = pd.DataFrame(recommendation_list, columns = [movieName])
    # Add this dataframe to the old one
    #recommendations_df = recommendations_df.join(new_rec_DF)
    recommendations_df = pd.concat([recommendations_df, new_rec_df], axis=1)
    return recommendations_df

# %% [markdown]
# At this point, we haven't generated any real-time events yet; we have only set up the code. To compare the recommendations before and after the real-time events, let's pick one user and generate the original recommendations for them.

# %%
# Get recommendations for the user
get_recommendations_response = personalize_runtime.get_recommendations(
        recommenderArn = recommender_top_picks_arn,
        userId = str(rerank_user),
    )

# Build a new dataframe for the recommendations
itemList = get_recommendations_response['itemList']
recommendationList = []
for item in item_list:
    artist = get_movie_by_id(item['itemId'])
    recommendationList.append(artist)
user_recommendations_df = pd.DataFrame(recommendationList, columns = [rerank_user])
user_recommendations_df
# Out:
#                                                109510
# 0                            Secret Agent, The (1996)
# 1                          Les Loups entre eux (1985)
# 2   Sometimes Happiness, Sometimes Sorrow (Kabhi K...
# 3                        Talk About a Stranger (1952)
# 4                        Once Upon a Honeymoon (1942)
# 5               Man There Was, A (Terje Vigen) (1917)
# 6                             The General Line (1929)
# 7               The Seashell and the Clergyman (1928)
# 8                                Evil Thoughts (1976)
# 9         Enron: The Smartest Guys in the Room (2005)
# 10                             Zero Years, The (2005)
# 11                               Never Forever (2007)
# 12                          Operation Daybreak (1975)
# 13                               The Outriders (1950)
# 14                          Stonewall Uprising (2010)
# 15                     Shriek of the Mutilated (1974)
# 16                              Ora o mai piÃ¹ (2003)
# 17                                     8 Dates (2008)
# 18                           American Pastoral (2016)
# 19                                 Saint Maybe (1998)
# 20                                    Consumed (2015)
# 21                   Princess for Christmas, A (2011)
# 22                               Crooked House (2017)
# 23                                  Tank Force (1958)
# 24                                       Zenda (2009)

# %% [markdown]
# Ok, so now we have a list of recommendations for this user before we have applied any real-time events. Now let's pick 3 random artists which we will simulate our user interacting with, and then see how this changes the recommendations.

# %%
# Next generate 3 random movies
movies = items_df.sample(3).index.tolist()

# %%
# Note this will take about 15 seconds to complete due to the sleeps
for movie in movies:
    user_recommendations_df = get_new_recommendations_df_users_real_time(user_recommendations_df, rerank_user, movie,'click')
    time.sleep(5)
# Out:
# sending event click for Black Room, The (1935)
# sending event click for Last Emperor, The (1987)
# sending event click for Zombieland (2009)

# %% [markdown]
# Now we can look at how the click events changed the recommendations.

# %%
user_recommendations_df
# Out:
#                                                109510  \
# 0                            Secret Agent, The (1996)
# 1                          Les Loups entre eux (1985)
# 2   Sometimes Happiness, Sometimes Sorrow (Kabhi K...
# 3                        Talk About a Stranger (1952)
# 4                        Once Upon a Honeymoon (1942)
# 5               Man There Was, A (Terje Vigen) (1917)
# 6                             The General Line (1929)
# 7               The Seashell and the Clergyman (1928)
# 8                                Evil Thoughts (1976)
# 9         Enron: The Smartest Guys in the Room (2005)
# 10                             Zero Years, The (2005)
# 11                               Never Forever (2007)
# 12                          Operation Daybreak (1975)
# 13                               The Outriders (1950)
# 14                          Stonewall Uprising (2010)
# 15                     Shriek of the Mutilated (1974)
# 16                              Ora o mai piÃ¹ (2003)
# 17                                     8 Dates (2008)
# 18                           American Pastoral (2016)
# 19                                 Saint Maybe (1998)
# 20                                    Consumed (2015)
# 21                   Princess for Christmas, A (2011)
# 22                               Crooked House (2017)
# 23                                  Tank Force (1958)
# 24                                       Zenda (2009)
#
#                                Black Room, The (1935)  \
# 0                         Love & Human Remains (1993)
# 1   In the Realm of the Senses (Ai no corrida) (1976)
# 2                                        Naked (1993)
# 3                                      Exotica (1994)
# 4                                        Nadja (1994)
# 5                                  Killing Zoe (1994)
# 6                                      Amateur (1994)
# 7                                 Strange Days (1995)
# 8                                        Faces (1968)
# 9                            Romeo Is Bleeding (1993)
# 10                              Body Snatchers (1993)
# 11           Beauty of the Day (Belle de jour) (1967)
# 12                           Ladybird Ladybird (1994)
# 13                                  Four Rooms (1995)
# 14                               Little Odessa (1994)
# 15          Mrs. Parker and the Vicious Circle (1994)
# 16                       Kicking and Screaming (1995)
# 17                                 Bitter Moon (1992)
# 18                        What Happened Was... (1994)
# 19                            Blue in the Face (1995)
# 20                                    Dead Man (1995)
# 21                                Blade Runner (1982)
# 22                                  Kalifornia (1993)
# 23                                    Clockers (1995)
# 24                  Purple Noon (Plein soleil) (1960)
#
#                              Last Emperor, The (1987)  \
# 0                         Love & Human Remains (1993)
# 1   In the Realm of the Senses (Ai no corrida) (1976)
# 2                                        Naked (1993)
# 3                                      Exotica (1994)
# 4                                        Nadja (1994)
# 5                                  Killing Zoe (1994)
# 6                                      Amateur (1994)
# 7                                 Strange Days (1995)
# 8                                        Faces (1968)
# 9                            Romeo Is Bleeding (1993)
# 10                              Body Snatchers (1993)
# 11           Beauty of the Day (Belle de jour) (1967)
# 12                           Ladybird Ladybird (1994)
# 13                                  Four Rooms (1995)
# 14                               Little Odessa (1994)
# 15          Mrs. Parker and the Vicious Circle (1994)
# 16                       Kicking and Screaming (1995)
# 17                                 Bitter Moon (1992)
# 18                        What Happened Was... (1994)
# 19                            Blue in the Face (1995)
# 20                                    Dead Man (1995)
# 21                                Blade Runner (1982)
# 22                                  Kalifornia (1993)
# 23                                    Clockers (1995)
# 24                  Purple Noon (Plein soleil) (1960)
#
#                                     Zombieland (2009)
# 0                            Last Emperor, The (1987)
# 1                             Bonnie and Clyde (1967)
# 2                            Dial M for Murder (1954)
# 3                                  Raging Bull (1980)
# 4                                 Blade Runner (1982)
# 5                        Rebel Without a Cause (1955)
# 6   Mary Shelley's Frankenstein (Frankenstein) (1994)
# 7                                 Strange Days (1995)
# 8                         Fish Called Wanda, A (1988)
# 9                            Menace II Society (1993)
# 10                                       Naked (1993)
# 11  Adventures of Priscilla, Queen of the Desert, ...
# 12                                        Wolf (1994)
# 13   Three Colors: Blue (Trois couleurs: Bleu) (1993)
# 14                                  Serial Mom (1994)
# 15                            Crying Game, The (1992)
# 16                          Lawnmower Man, The (1992)
# 17                                  Casablanca (1942)
# 18                                  Carrington (1995)
# 19                   Six Degrees of Separation (1993)
# 20                         Maltese Falcon, The (1941)
# 21                                     Platoon (1986)
# 22   Three Colors: Red (Trois couleurs: Rouge) (1994)
# 23                   Streetcar Named Desire, A (1951)
# 24                         Glengarry Glen Ross (1992)

# %% [markdown]
# In the cell above, the first column after the index is the user's default recommendations from the "Top pics for you" recommender, and each column after that has as a header of the movie that they interacted with via a real time event, and the recommendations after this event occurred.
#
# The behavior may not shift very much or a lot; this is due to the relatively limited nature of this dataset and effect of a few random clicks. If you wanted to better understand this, try simulating clicking more movies to see the impact.

# %% [markdown]
# Now lets look at the event filters, which allow you to filter items based on the interaction data. For this dataset, it could be click or watch based on the data we imported, but could be based on whatever interaction schema you design (click, rate, like, watch, purchase etc.)
#
# We will create a new helper function to use the personalized ranking campaign, sice the Recommenders already filter out watched content.

# %%
def get_new_ranked_recommendations_df_by_static_filter(recommendations_df, user_id, rerank_item_list, filter_arn):
    
    # Get the recommendations
    get_recommendations_response = personalize_runtime.get_personalized_ranking(
        campaignArn = rerank_campaign_arn,
        userId = str(user_id),
        inputList = rerank_item_list,
        filterArn = filter_arn
    )
    # Build a new dataframe of recommendations
    item_list = get_recommendations_response['personalizedRanking']
    recommendation_list = []
    for item in item_list:
        movie = get_movie_by_id(item['itemId'])
        recommendation_list.append(movie)

    filter_name = filter_arn.split('/')[1]
    new_rec_df = pd.DataFrame(recommendation_list, columns = [filter_name])
    # Add this dataframe to the old one
    recommendations_df = pd.concat([recommendations_df, new_rec_df], axis=1)
    return recommendations_df

# %%
recommendations_df_events = pd.DataFrame()
for filter_arn in interaction_filter_arns:
    recommendations_df_events = get_new_ranked_recommendations_df_by_static_filter(recommendations_df_events, rerank_user, rerank_item_list, filter_arn)
    
recommendations_df_events
# Out:
#    watched                                          unwatched
# 0      NaN                           Secret Agent, The (1996)
# 1      NaN                         Les Loups entre eux (1985)
# 2      NaN                          Stonewall Uprising (2010)
# 3      NaN                       Once Upon a Honeymoon (1942)
# 4      NaN                                     8 Dates (2008)
# 5      NaN                       Talk About a Stranger (1952)
# 6      NaN                               Never Forever (2007)
# 7      NaN              The Seashell and the Clergyman (1928)
# 8      NaN  Sometimes Happiness, Sometimes Sorrow (Kabhi K...
# 9      NaN        Enron: The Smartest Guys in the Room (2005)
# 10     NaN              Man There Was, A (Terje Vigen) (1917)
# 11     NaN                            The General Line (1929)
# 12     NaN                              Ora o mai piÃ¹ (2003)
# 13     NaN                     Shriek of the Mutilated (1974)
# 14     NaN                             Zero Years, The (2005)
# 15     NaN                               The Outriders (1950)
# 16     NaN                               Evil Thoughts (1976)
# 17     NaN                          Operation Daybreak (1975)
# 18     NaN                   Princess for Christmas, A (2011)
# 19     NaN                               Crooked House (2017)
# 20     NaN                                    Consumed (2015)
# 21     NaN                           American Pastoral (2016)
# 22     NaN                                       Zenda (2009)
# 23     NaN                                 Saint Maybe (1998)
# 24     NaN                                  Tank Force (1958)

# %% [markdown]
# Now lets send a watch event in for the top 4 unwatched recommendations, which would simulate watching 4 movies. In a VOD application, you may choose to send in an event after they have watched a significant amount (over 75%) of a piece of content. Sending at 100% complete could miss people that stop short of the credits.

# %%
ranked_unwatched_recommendations_response = personalize_runtime.get_personalized_ranking(
    campaignArn = rerank_campaign_arn,
    userId = str(rerank_user),
    inputList = rerank_item_list,
    filterArn = filter_arn)

item_list = ranked_unwatched_recommendations_response['personalizedRanking'][:4]

for item in item_list:
    print('sending event watch for ' + get_movie_by_id(item['itemId']))
    send_movie_click(userId=rerank_user, itemId=item['itemId'], eventType='Watch')
    time.sleep(10)
# Out:
# sending event watch for Secret Agent, The (1996)
# sending event watch for Les Loups entre eux (1985)
# sending event watch for Stonewall Uprising (2010)
# sending event watch for Once Upon a Honeymoon (1942)

# %% [markdown]
# Now we can look at the event filters to see the updated watched and unwatched recommendations

# %%
recommendations_df_events = pd.DataFrame()
for filter_arn in interaction_filter_arns:
    recommendations_df_events = get_new_ranked_recommendations_df_by_static_filter(recommendations_df_events, rerank_user, rerank_item_list, filter_arn)
recommendations_df_events
# Out:
#                          watched  \
# 0   Once Upon a Honeymoon (1942)
# 1       Secret Agent, The (1996)
# 2      Stonewall Uprising (2010)
# 3     Les Loups entre eux (1985)
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
#
#                                             unwatched
# 0   Sometimes Happiness, Sometimes Sorrow (Kabhi K...
# 1               The Seashell and the Clergyman (1928)
# 2                        Talk About a Stranger (1952)
# 3                                Never Forever (2007)
# 4               Man There Was, A (Terje Vigen) (1917)
# 5                             The General Line (1929)
# 6                                      8 Dates (2008)
# 7         Enron: The Smartest Guys in the Room (2005)
# 8                                The Outriders (1950)
# 9                                Evil Thoughts (1976)
# 10                              Ora o mai piÃ¹ (2003)
# 11                             Zero Years, The (2005)
# 12                     Shriek of the Mutilated (1974)
# 13                   Princess for Christmas, A (2011)
# 14                          Operation Daybreak (1975)
# 15                                       Zenda (2009)
# 16                                  Tank Force (1958)
# 17                                 Saint Maybe (1998)
# 18                               Crooked House (2017)
# 19                           American Pastoral (2016)
# 20                                    Consumed (2015)

# %% [markdown]
# ## Batch Recommendations <a class="anchor" id="batch"></a>
# [Back to top](#top)
#
# There are many cases where you may want to have a larger dataset of exported recommendations. Amazon Personalize launched batch recommendations as a way to export a collection of recommendations to S3. In this example, we will walk through how to do this for the Personalized Ranking solution. For more information about batch recommendations, please see the [documentation](https://docs.aws.amazon.com/personalize/latest/dg/recommendations-batch.html). This feature applies to all recipes, but the output format will vary.
#
# A simple implementation looks like this:
#
# ```python
# import boto3
#
# personalize_rec = boto3.client(service_name='personalize')
#
# personalize_rec.create_batch_inference_job (
#     solutionVersionArn = "Solution version ARN",
#     jobName = "Batch job name",
#     roleArn = "IAM role ARN",
#     jobInput =
#        {"s3DataSource": {"path": <S3 input path>}},
#     jobOutput =
#        {"s3DataDestination": {"path": <S3 output path>}}
# )
# ```
#
# The SDK import, the solution version arn, and role arns have all been determined. This just leaves an input, an output, and a job name to be defined.
#
# Starting with the input for Personalized Ranking, it looks like:
#
#
# ```JSON
# {"userId": "891", "itemList": ["27", "886", "101"]}
# {"userId": "445", "itemList": ["527", "55", "901"]}
# {"userId": "71", "itemList": ["27", "351", "101"]}
# ```
#
# This should yield an output that looks like this:
#
# ```JSON
# {"input":{"userId":"891","itemList":["27","886","101"]},"output":{"recommendedItems":["27","101","886"],"scores":[0.48421,0.28133,0.23446]}}
# {"input":{"userId":"445","itemList":["527","55","901"]},"output":{"recommendedItems":["901","527","55"],"scores":[0.46972,0.31011,0.22017]}}
# {"input":{"userId":"71","itemList":["29","351","199"]},"output":{"recommendedItems":["351","29","199"],"scores":[0.68937,0.24829,0.06232]}}
#
# ```
#
# The output is a JSON Lines file. It consists of individual JSON objects, one per line. So we will need to put in more work later to digest the results in this format.

# %% [markdown]
# ### Building the input file
#
# When you are using the batch feature, you specify the users that you'd like to receive recommendations for when the job has completed. The cell below will again select a few random users and will then build the file and save it to disk. From there, you will upload it to S3 to use in the API call later.

# %%
# We will use the same users from before
print (users)
# Write the file to disk
json_input_filename = "json_input.json"
with open(data_dir + "/" + json_input_filename, 'w') as json_input:
    for user_id in users:
        json_input.write('{"userId": "' + str(user_id) + '", "itemList":'+json.dumps(rerank_item_list)+'}\n')
# Out:
# [28783, 84713, 109510]

# %%
# Showcase the input file:
# !cat $data_dir"/"$json_input_filename
# Out:
# {"userId": "28783", "itemList":["107563", "202599", "78629", "124703", "86985", "96522", "136568", "139693", "146090", "153740", "101319", "31340", "200934", "27362", "133616", "165441", "165727", "160976", "123077", "178839", "74127", "154009", "75335", "1040", "175395"]}
# {"userId": "84713", "itemList":["107563", "202599", "78629", "124703", "86985", "96522", "136568", "139693", "146090", "153740", "101319", "31340", "200934", "27362", "133616", "165441", "165727", "160976", "123077", "178839", "74127", "154009", "75335", "1040", "175395"]}
# {"userId": "109510", "itemList":["107563", "202599", "78629", "124703", "86985", "96522", "136568", "139693", "146090", "153740", "101319", "31340", "200934", "27362", "133616", "165441", "165727", "160976", "123077", "178839", "74127", "154009", "75335", "1040", "175395"]}

# %% [markdown]
# Upload the file to S3 and save the path as a variable for later.

# %%
# Upload files to S3
boto3.Session().resource('s3').Bucket(bucket_name).Object(json_input_filename).upload_file(data_dir+"/"+json_input_filename)
s3_input_path = "s3://" + bucket_name + "/" + json_input_filename
print(s3_input_path)
# Out:
# s3://061703360474-us-east-1-personalizepocvod/json_input.json

# %% [markdown]
# Batch recommendations read the input from the file we've uploaded to S3. Similarly, batch recommendations will save the output to file in S3. So we define the output path where the results should be saved.

# %%
# Define the output path
s3_output_path = "s3://" + bucket_name + "/"
print(s3_output_path)
# Out:
# s3://061703360474-us-east-1-personalizepocvod/

# %% [markdown]
# Now just make the call to kick off the batch export process.

# %%
batchInferenceJobArn = personalize.create_batch_inference_job (
    solutionVersionArn = rerank_solution_version_arn,
    jobName = "VOD-POC-Batch-Inference-Job-PersonalizedRanking_" + str(round(time.time()*1000)),
    roleArn = role_arn,
    jobInput = 
     {"s3DataSource": {"path": s3_input_path}},
    jobOutput = 
     {"s3DataDestination":{"path": s3_output_path}}
)
batchInferenceJobArn = batchInferenceJobArn['batchInferenceJobArn']

# %% [markdown]
# Run the while loop below to track the status of the batch recommendation call. This can take around 30 minutes to complete, because Personalize needs to stand up the infrastructure to perform the task. We are testing the feature with a dataset of only 3 users, which is not an efficient use of this mechanism. Normally, you would only use this feature for bulk processing, in which case the efficiencies will become clear.

# %%
current_time = datetime.now()
print("Import Started on: ", current_time.strftime("%I:%M:%S %p"))

max_time = time.time() + 6*60*60 # 6 hours
while time.time() < max_time:
    describe_dataset_inference_job_response = personalize.describe_batch_inference_job(
        batchInferenceJobArn = batchInferenceJobArn
    )
    status = describe_dataset_inference_job_response["batchInferenceJob"]['status']
    print("DatasetInferenceJob: {}".format(status))
    
    if status == "ACTIVE" or status == "CREATE FAILED":
        break
        
    time.sleep(60)
    
current_time = datetime.now()
print("Import Completed on: ", current_time.strftime("%I:%M:%S %p"))
# Out:
# Import Started on:  11:38:30 AM
# DatasetInferenceJob: CREATE PENDING
# DatasetInferenceJob: CREATE IN_PROGRESS
# DatasetInferenceJob: CREATE IN_PROGRESS
# DatasetInferenceJob: CREATE IN_PROGRESS
# DatasetInferenceJob: CREATE IN_PROGRESS
# DatasetInferenceJob: CREATE IN_PROGRESS
# DatasetInferenceJob: CREATE IN_PROGRESS
# DatasetInferenceJob: CREATE IN_PROGRESS
# DatasetInferenceJob: CREATE IN_PROGRESS
# DatasetInferenceJob: CREATE IN_PROGRESS
# DatasetInferenceJob: CREATE IN_PROGRESS
# DatasetInferenceJob: CREATE IN_PROGRESS
# DatasetInferenceJob: CREATE IN_PROGRESS
# DatasetInferenceJob: ACTIVE
# Import Completed on:  11:51:31 AM

# %%
s3 = boto3.client('s3')
export_name = json_input_filename + ".out"
s3.download_file(bucket_name, export_name, data_dir+"/"+export_name)

# Update DF rendering
pd.set_option('display.max_rows', 30)
with open(data_dir+"/"+export_name) as json_file:
    # Get the first line and parse it
    line = json.loads(json_file.readline())
    # Do the same for the other lines
    while line:
        # extract the user ID 
        col_header = "User: " + line['input']['userId']
        # Create a list for all the artists
        recommendation_list = []
        # Add all the entries
        for item in line['output']['recommendedItems']:
            movie = get_movie_by_id(item)
            recommendation_list.append(movie)
        if 'bulk_recommendations_df' in locals():
            new_rec_DF = pd.DataFrame(recommendation_list, columns = [col_header])
            try:
                bulk_recommendations_df = bulk_recommendations_df.join(new_rec_DF)
            except:
                bulk_recommendations_df = bulk_recommendations_df
        else:
            bulk_recommendations_df = pd.DataFrame(recommendation_list, columns=[col_header])
        try:
            line = json.loads(json_file.readline())
        except:
            line = None
bulk_recommendations_df
# Out:
#                                             User: 526  \
# 0                                      Virunga (2014)
# 1                     PelÃ©: Birth of a Legend (2016)
# 2                                     Magnolia (1999)
# 3       American Drug War: The Last White Hope (2007)
# 4                          Golden Compass, The (2007)
# 5                                     Trekkies (1997)
# 6                                         Moon (2009)
# 7                           Mark of Zorro, The (1940)
# 8   Battle Royale 2: Requiem (Batoru rowaiaru II: ...
# 9                                     Casanova (2005)
# 10                                     Valiant (2005)
# 11                          My Boss's Daughter (2003)
# 12                       Age of Innocence, The (1993)
# 13             How the Grinch Stole Christmas! (1966)
# 14                                     Copycat (1995)
# 15                               Scary Movie 2 (2001)
# 16                       Railway Children, The (1970)
# 17                    Night of the Iguana, The (1964)
# 18                                  Radio Days (1987)
# 19                              Big Tease, The (1999)
# 20                                  Funny Farm (1988)
# 21                          A Man Called Blade (1977)
# 22                                 Peeping Tom (1960)
# 23                              Innocents, The (1961)
# 24                          Scenes from a Mall (1991)
#
#                                             User: 291  \
# 0                          Golden Compass, The (2007)
# 1                                     Casanova (2005)
# 2                     PelÃ©: Birth of a Legend (2016)
# 3                                         Moon (2009)
# 4                                     Magnolia (1999)
# 5   Battle Royale 2: Requiem (Batoru rowaiaru II: ...
# 6                                      Valiant (2005)
# 7                                Scary Movie 2 (2001)
# 8                                      Virunga (2014)
# 9                           My Boss's Daughter (2003)
# 10                          Mark of Zorro, The (1940)
# 11             How the Grinch Stole Christmas! (1966)
# 12                       Railway Children, The (1970)
# 13                                  Radio Days (1987)
# 14                    Night of the Iguana, The (1964)
# 15                                 Peeping Tom (1960)
# 16                              Innocents, The (1961)
# 17                              Big Tease, The (1999)
# 18                          A Man Called Blade (1977)
# 19                                  Funny Farm (1988)
# 20                          Scenes from a Mall (1991)
# 21                       Age of Innocence, The (1993)
# 22      American Drug War: The Last White Hope (2007)
# 23                                     Copycat (1995)
# 24                                    Trekkies (1997)
#
#                                             User: 426
# 0                           My Boss's Daughter (2003)
# 1                                Scary Movie 2 (2001)
# 2              How the Grinch Stole Christmas! (1966)
# 3                                     Casanova (2005)
# 4                          Golden Compass, The (2007)
# 5                                         Moon (2009)
# 6                                   Funny Farm (1988)
# 7                                     Magnolia (1999)
# 8                                      Valiant (2005)
# 9                               Big Tease, The (1999)
# 10                                  Radio Days (1987)
# 11                       Railway Children, The (1970)
# 12      American Drug War: The Last White Hope (2007)
# 13                                     Copycat (1995)
# 14                          Scenes from a Mall (1991)
# 15                          Mark of Zorro, The (1940)
# 16                    Night of the Iguana, The (1964)
# 17                                    Trekkies (1997)
# 18                       Age of Innocence, The (1993)
# 19                                     Virunga (2014)
# 20                    PelÃ©: Birth of a Legend (2016)
# 21                          A Man Called Blade (1977)
# 22                                 Peeping Tom (1960)
# 23                              Innocents, The (1961)
# 24  Battle Royale 2: Requiem (Batoru rowaiaru II: ...

# %% [markdown]
# #### Batch Inference for Segmentation

# %% [markdown]
# First let's create the input file.  This is a file that lists each item id
#
# Reference - https://github.com/aws-samples/amazon-personalize-samples/blob/master/next_steps/core_use_cases/user_segmentation/user_segmentation_example.ipynb

# %%
interactions_df = pd.read_csv((data_dir+"/interactions.csv"))

# %%
interactions_df.head()
# Out:
#    USER_ID  ITEM_ID  TIMESTAMP EVENT_TYPE
# 0     2262     1079  789652009      Click
# 1     2262       47  789652009      Click
# 2     2262       21  789652009      Click
# 3     2262       47  789652009      Watch
# 4   102689       47  822873600      Click

# %%
item_ids = interactions_df[(interactions_df['USER_ID']==426)&(interactions_df['EVENT_TYPE']=='Watch')]['ITEM_ID'].values

# %%
# Write the file to disk
json_input_filename = "json_input_items.json"
with open(data_dir + "/" + json_input_filename, 'w') as json_input:
    for item_id in item_ids:
        json_input.write('{"itemId": "'+str(item_id)+'"}\n')

# %%
# Upload files to S3
boto3.Session().resource('s3').Bucket(bucket_name).Object(json_input_filename).upload_file(data_dir+"/"+json_input_filename)
s3_input_path = "s3://" + bucket_name + "/" + json_input_filename
s3_output_path = "s3://"+bucket_name+"/output/"
print(s3_input_path)
# Out:
# s3://061703360474-us-east-1-personalizepocvod/json_input_items.json

# %%
# change the jobName if already exists
create_batch_segment_response = personalize.create_batch_segment_job(
    jobName = "notebook-query-demo-500",
    solutionVersionArn = itemaffinity_solution_version_arn,
    numResults = 500,
    jobInput =  {
        "s3DataSource": {
            "path": s3_input_path
        }
    },
    jobOutput = {
        "s3DataDestination": {
            "path": s3_output_path
        }
    },
    roleArn = role_arn # defined in Step 1.4.2
    )

batch_segment_job_arn = create_batch_segment_response['batchSegmentJobArn']
print(batch_segment_job_arn)
# Out:
# arn:aws:personalize:us-east-1:061703360474:batch-segment-job/notebook-query-demo-500

# %%
def wait_for_batch_segment_job(batch_segment_job_arn):
    max_time = time.time() + 3 * 60 * 60
    while time.time() < max_time:
        describe_job_response = personalize.describe_batch_segment_job(
            batchSegmentJobArn = batch_segment_job_arn
        )
        status = describe_job_response["batchSegmentJob"]["status"]
        print("Batch Segment Job: {}".format(status))

        start = describe_job_response["batchSegmentJob"]["creationDateTime"]
        end = describe_job_response["batchSegmentJob"]["lastUpdatedDateTime"]
        if status == "ACTIVE":
            print("Time took: {}".format(end - start))
            break
        if status == "CREATE FAILED":
            print("Time took: {}".format(end - start))
            print("Job Failed: {}".format(describe_job_response["batchSegmentJob"]["failureReason"]))
            break

        time.sleep(180)

# %%
wait_for_batch_segment_job(batch_segment_job_arn)
# Out:
# Batch Segment Job: CREATE IN_PROGRESS
# Batch Segment Job: CREATE IN_PROGRESS
# Batch Segment Job: CREATE IN_PROGRESS
# Batch Segment Job: CREATE IN_PROGRESS
# Batch Segment Job: CREATE IN_PROGRESS
# Batch Segment Job: CREATE IN_PROGRESS
# Batch Segment Job: CREATE IN_PROGRESS
# Batch Segment Job: CREATE IN_PROGRESS
# Batch Segment Job: CREATE IN_PROGRESS
# Batch Segment Job: ACTIVE
# Time took: 0:26:02.535000

# %%
output_file_name_s3 = s3_output_path+json_input_filename+".out"
output=pd.read_json(output_file_name_s3, lines = True)
prediction=output.apply(lambda x:pd.Series({'ITEM_ID':x['input']['itemId'],'USER_ID':x['output']['usersList']}),axis=1).set_index('ITEM_ID')['USER_ID']
output.sample(3)
# Out:
#                  input                                             output  \
# 16  {'itemId': '3360'}  {'usersList': ['68211', '130751', '139043', '3...
# 92  {'itemId': '2313'}  {'usersList': ['68241', '7897', '38099', '2288...
# 24  {'itemId': '2502'}  {'usersList': ['24624', '65407', '117954', '71...
#
#     error
# 16    NaN
# 92    NaN
# 24    NaN

# %% [markdown]
# ## Wrap up <a class="anchor" id="wrapup"></a>
# [Back to top](#top)
#
# With that you now have a fully working collection of models to tackle various recommendation and personalization scenarios, as well as the skills to manipulate customer data to better integrate with the service, and a knowledge of how to do all this over APIs and by leveraging open source data science tools.
#
# Use these notebooks as a guide to getting started with your customers for POCs. As you find missing components, or discover new approaches, make a pull request and provide any additional helpful components that may be missing from this collection.
#
# You can choose to head to `04_Operations_Layer.ipynb` to go deeper into ML Ops and what a production solution can look like with an automation pipeline.
#
# You'll want to make sure that you clean up all of the resources deployed during this POC. We have provided a separate notebook which shows you how to identify and delete the resources in `05_Clean_Up.ipynb`.

# %%
# %store event_tracker_arn
# %store batchInferenceJobArn
